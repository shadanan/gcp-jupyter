# %% [markdown]
# # Setup

# %%
import json

import pandas as pd
from google.cloud import securitycenter_v1
from tqdm.auto import tqdm

pd.set_option("display.max_rows", 1000)
pd.set_option("display.max_colwidth", None)

# %% [markdown]
# # Functions

# %%
scc_client = securitycenter_v1.SecurityCenterClient()


def get_finding_configs():
    with open("finding_configs.json", "r") as fp:
        return json.load(fp)


def get_findings(org_id):
    resp = scc_client.list_findings(
        securitycenter_v1.ListFindingsRequest(
            parent=f"organizations/{org_id}/sources/-",
            page_size=1000,
        )
    )
    return tqdm(resp, total=resp.total_size, unit="findings", desc="Loading Findings")


def get_assets(org_id):
    resp = scc_client.list_assets(
        securitycenter_v1.ListAssetsRequest(
            parent=f"organizations/{org_id}",
            page_size=1000,
        )
    )
    return tqdm(resp, total=resp.total_size, unit="assets", desc="Loading Assets")

# %% [markdown]
# # Load Data

# %%
org_id = "215365938848"
findings = list(get_findings(org_id))
assets = list(get_assets(org_id))
finding_configs = get_finding_configs()
# Out:
# Loading Findings:   0%|          | 0/10862 [00:00<?, ?findings/s]
# Loading Assets:   0%|          | 0/8403 [00:00<?, ?assets/s]

# %% [markdown]
# # Create Dataframes

# %%
adf = pd.DataFrame(
    [
        (
            a.asset.security_center_properties.resource_name,
            a.asset.security_center_properties.resource_type,
            a.asset.security_center_properties.resource_project,
            a.asset.security_center_properties.resource_owners,
        )
        for a in assets
    ],
    columns=["resource_name", "resource_type", "project", "owners"],
)

fdf = pd.DataFrame(
    [(f.finding.resource_name, f.finding.category, 1) for f in findings],
    columns=["resource_name", "category", "count"],
)

mdf = pd.DataFrame(
    [
        (
            resource_type,
            m["finding_type"],
            m["severity"],
            list(m["compliance_metadata"].keys()),
        )
        for m in finding_configs
        for resource_type in m["resource_types"]
    ],
    columns=["resource_type", "category", "severity", "benchmarks"],
)

# %%
adf.head()
# Out:
#                                                       resource_name  \
# 0  //cloudresourcemanager.googleapis.com/organizations/215365938848
# 1       //cloudresourcemanager.googleapis.com/projects/469450300351
# 2       //cloudresourcemanager.googleapis.com/projects/350556640222
# 3       //cloudresourcemanager.googleapis.com/projects/225465665268
# 4      //cloudresourcemanager.googleapis.com/projects/1021433544460
#
#                                resource_type  \
# 0  google.cloud.resourcemanager.Organization
# 1       google.cloud.resourcemanager.Project
# 2       google.cloud.resourcemanager.Project
# 3       google.cloud.resourcemanager.Project
# 4       google.cloud.resourcemanager.Project
#
#                                                         project  \
# 0
# 1   //cloudresourcemanager.googleapis.com/projects/469450300351
# 2   //cloudresourcemanager.googleapis.com/projects/350556640222
# 3   //cloudresourcemanager.googleapis.com/projects/225465665268
# 4  //cloudresourcemanager.googleapis.com/projects/1021433544460
#
#                          owners
# 0                            []
# 1   [user:shubaiyer@google.com]
# 2  [user:bensanders@google.com]
# 3         [user:qxl@google.com]
# 4    [user:anniemao@google.com]

# %%
fdf.head()
# Out:
#                                                                                                        resource_name  \
# 0                 //compute.googleapis.com/projects/es-demo-prod/regions/asia-south1/subnetworks/3759943304756592809
# 1  //compute.googleapis.com/projects/iap-managed-instance-group-fr/zones/us-central1-a/instances/6071295769166118608
# 2  //compute.googleapis.com/projects/iap-managed-instance-group-fr/zones/us-central1-a/instances/3302980516996567441
# 3                                                        //cloudresourcemanager.googleapis.com/projects/891045812741
# 4  //compute.googleapis.com/projects/iap-managed-instance-group-fr/zones/us-central1-a/instances/3674588702404281108
#
#                        category  count
# 0            FLOW_LOGS_DISABLED      1
# 1  COMPUTE_SECURE_BOOT_DISABLED      1
# 2  DEFAULT_SERVICE_ACCOUNT_USED      1
# 3     CUSTOM_ROLE_NOT_MONITORED      1
# 4             PUBLIC_IP_ADDRESS      1

# %%
mdf.head()
# Out:
#                                resource_type                   category  \
# 0  google.cloud.resourcemanager.Organization      ADMIN_SERVICE_ACCOUNT
# 1        google.cloud.resourcemanager.Folder      ADMIN_SERVICE_ACCOUNT
# 2       google.cloud.resourcemanager.Project      ADMIN_SERVICE_ACCOUNT
# 3       google.cloud.resourcemanager.Project  API_KEY_APIS_UNRESTRICTED
# 4       google.cloud.resourcemanager.Project  API_KEY_APPS_UNRESTRICTED
#
#   severity                          benchmarks
# 0   MEDIUM  [CIS 1.0 Level 1, CIS 1.1 Level 1]
# 1   MEDIUM  [CIS 1.0 Level 1, CIS 1.1 Level 1]
# 2   MEDIUM  [CIS 1.0 Level 1, CIS 1.1 Level 1]
# 3   MEDIUM  [CIS 1.0 Level 1, CIS 1.1 Level 1]
# 4   MEDIUM  [CIS 1.0 Level 1, CIS 1.1 Level 1]

# %% [markdown]
# # Merge

# %%
df = (
    adf.merge(mdf, on="resource_type")
    .merge(fdf, how="left", on=["resource_name", "category"])
    .assign(count=lambda tdf: tdf["count"].fillna(0).astype(int))
)
df
# Out:
#                                                                                                                      resource_name  \
# 0                                                                 //cloudresourcemanager.googleapis.com/organizations/215365938848
# 1                                                                 //cloudresourcemanager.googleapis.com/organizations/215365938848
# 2                                                                 //cloudresourcemanager.googleapis.com/organizations/215365938848
# 3                                                                 //cloudresourcemanager.googleapis.com/organizations/215365938848
# 4                                                                 //cloudresourcemanager.googleapis.com/organizations/215365938848
# ...                                                                                                                            ...
# 14452           //compute.googleapis.com/projects/archery-range-test/zones/us-central1-b/networkEndpointGroups/7071147847689363169
# 14453           //compute.googleapis.com/projects/archery-range-test/zones/us-central1-c/networkEndpointGroups/7548110451310780153
# 14454  //compute.googleapis.com/projects/gclb-multi-service-test-app/zones/us-central1-a/networkEndpointGroups/4756782166325632152
# 14455                      //compute.googleapis.com/projects/css-gke-tests/regions/us-central1/backendServices/5717825367004480071
# 14456                   //compute.googleapis.com/projects/css-firing-range/regions/us-central1/backendServices/5270842051782260721
#
#                                    resource_type  \
# 0      google.cloud.resourcemanager.Organization
# 1      google.cloud.resourcemanager.Organization
# 2      google.cloud.resourcemanager.Organization
# 3      google.cloud.resourcemanager.Organization
# 4      google.cloud.resourcemanager.Organization
# ...                                          ...
# 14452        google.compute.NetworkEndpointGroup
# 14453        google.compute.NetworkEndpointGroup
# 14454        google.compute.NetworkEndpointGroup
# 14455        google.compute.RegionBackendService
# 14456        google.compute.RegionBackendService
#
#                                                            project  \
# 0
# 1
# 2
# 3
# 4
# ...                                                            ...
# 14452  //cloudresourcemanager.googleapis.com/projects/705883220659
# 14453  //cloudresourcemanager.googleapis.com/projects/705883220659
# 14454   //cloudresourcemanager.googleapis.com/projects/68404284703
# 14455  //cloudresourcemanager.googleapis.com/projects/491846130587
# 14456  //cloudresourcemanager.googleapis.com/projects/750472880964
#
#                                                                                                                                                                                                                                                                                                                             owners  \
# 0                                                                                                                                                                                                                                                                                                                               []
# 1                                                                                                                                                                                                                                                                                                                               []
# 2                                                                                                                                                                                                                                                                                                                               []
# 3                                                                                                                                                                                                                                                                                                                               []
# 4                                                                                                                                                                                                                                                                                                                               []
# ...                                                                                                                                                                                                                                                                                                                            ...
# 14452                                                                                                                                                                                                                                                                 [user:bensanders@google.com, user:mariussteffens@google.com]
# 14453                                                                                                                                                                                                                                                                 [user:bensanders@google.com, user:mariussteffens@google.com]
# 14454                                                                                                                                                                                                                                                                         [user:anniemao@google.com, user:menglish@google.com]
# 14455                                                                                                                                                                                                                                                                                                   [user:ashishin@google.com]
# 14456  [serviceAccount:manually-test-by-qxl@css-firing-range.iam.gserviceaccount.com, user:EuronStark.753273@gmail.com, user:amauris@google.com, user:anniemao@google.com, user:cacui@google.com, user:chaofans@google.com, user:dazari@google.com, user:lincolnv@google.com, user:lmpatterson@google.com, user:rzheng@google.com]
#
#                               category severity  \
# 0                ADMIN_SERVICE_ACCOUNT   MEDIUM
# 1               AUDIT_LOGGING_DISABLED      LOW
# 2                  KMS_ROLE_SEPARATION   MEDIUM
# 3                     MFA_NOT_ENFORCED     HIGH
# 4                   NON_ORG_IAM_MEMBER     HIGH
# ...                                ...      ...
# 14452  ORG_POLICY_LOCATION_RESTRICTION   MEDIUM
# 14453  ORG_POLICY_LOCATION_RESTRICTION   MEDIUM
# 14454  ORG_POLICY_LOCATION_RESTRICTION   MEDIUM
# 14455  ORG_POLICY_LOCATION_RESTRICTION   MEDIUM
# 14456  ORG_POLICY_LOCATION_RESTRICTION   MEDIUM
#
#                                                benchmarks  count
# 0                      [CIS 1.0 Level 1, CIS 1.1 Level 1]      1
# 1      [CIS 1.0 Level 1, CIS 1.1 Level 1, PCI, NIST, ISO]      1
# 2           [CIS 1.0 Level 2, CIS 1.1 Level 2, NIST, ISO]      0
# 3      [CIS 1.0 Level 1, CIS 1.1 Level 1, PCI, NIST, ISO]      1
# 4      [CIS 1.0 Level 1, CIS 1.1 Level 1, PCI, NIST, ISO]      1
# ...                                                   ...    ...
# 14452                                                  []      0
# 14453                                                  []      0
# 14454                                                  []      0
# 14455                                                  []      0
# 14456                                                  []      0
#
# [14457 rows x 8 columns]

# %% [markdown]
# # Export

# %% [markdown]
# ## Findings per Asset

# %%
df.to_csv("verdicts.csv")

# %% [markdown]
# ## Assets

# %%
with open("assets.json", "w") as fp:
    json.dump([securitycenter_v1.Asset.to_dict(a.asset) for a in assets], fp)

# %% [markdown]
# ## Findings

# %%
with open("findings.json", "w") as fp:
    json.dump([securitycenter_v1.Finding.to_dict(f.finding) for f in findings], fp)

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Grouped by Benchmark

# %%
(
    df.explode("benchmarks")
    .groupby("benchmarks")
    .agg(
        vuln=pd.NamedAgg(column="count", aggfunc="sum"),
        total=pd.NamedAgg(column="count", aggfunc="count"),
    )
    .assign(vuln_percent=lambda tdf: tdf["vuln"] * 100 / tdf["total"])
)
# Out:
#                  vuln  total  vuln_percent
# benchmarks
# CIS 1.0 Level 1  2025   3040     66.611842
# CIS 1.0 Level 2  1337   3208     41.677057
# CIS 1.1 Level 1  1877   2922     64.236824
# CIS 1.1 Level 2   184    984     18.699187
# ISO              1723   7628     22.587834
# NIST             1701   7655     22.220771
# PCI              1812   8003     22.641509

# %% [markdown]
# ## Grouped by Benchmark and Filtered by Project

# %%
(
    df.query("project == '//cloudresourcemanager.googleapis.com/projects/705883220659'")
    .explode("benchmarks")
    .groupby("benchmarks")
    .agg(
        vuln=pd.NamedAgg(column="count", aggfunc="sum"),
        total=pd.NamedAgg(column="count", aggfunc="count"),
    )
    .assign(vuln_percent=lambda tdf: tdf["vuln"] * 100 / tdf["total"])
)
# Out:
#                  vuln  total  vuln_percent
# benchmarks
# CIS 1.0 Level 1    48     87     55.172414
# CIS 1.0 Level 2    33    157     21.019108
# CIS 1.1 Level 1    40     78     51.282051
# CIS 1.1 Level 2     3     35      8.571429
# ISO                42    218     19.266055
# NIST               41    222     18.468468
# PCI                45    240     18.750000

# %% [markdown]
# ## Grouped by Asset Type

# %%
(
    df.groupby(["resource_type"])
    .agg(
        vuln=pd.NamedAgg(column="count", aggfunc="sum"),
        total=pd.NamedAgg(column="count", aggfunc="count"),
    )
    .assign(vuln_percent=lambda tdf: tdf["vuln"] * 100 / tdf["total"])
)
# Out:
#                                               vuln  total  vuln_percent
# resource_type
# google.cloud.bigquery.Dataset                    0     10      0.000000
# google.cloud.dns.ManagedZone                     2      4     50.000000
# google.cloud.resourcemanager.Folder              0     42      0.000000
# google.cloud.resourcemanager.Organization        5      9     55.555556
# google.cloud.resourcemanager.Project           615   1326     46.380090
# google.cloud.sql.Instance                       13     54     24.074074
# google.cloud.storage.Bucket                    142    576     24.652778
# google.compute.Address                           0     38      0.000000
# google.compute.Autoscaler                        0      1      0.000000
# google.compute.Disk                              0    246      0.000000
# google.compute.Firewall                        312   5808      5.371901
# google.compute.ForwardingRule                    0      9      0.000000
# google.compute.HealthCheck                       0     24      0.000000
# google.compute.Instance                        130    810     16.049383
# google.compute.InstanceGroup                     0     31      0.000000
# google.compute.InstanceGroupManager              0     20      0.000000
# google.compute.Network                          39     84     46.428571
# google.compute.NetworkEndpointGroup              0      8      0.000000
# google.compute.Project                          39     39    100.000000
# google.compute.RegionBackendService              0      2      0.000000
# google.compute.Snapshot                          0      1      0.000000
# google.compute.SslCertificate                    0      9      0.000000
# google.compute.Subnetwork                     2463   3696     66.639610
# google.compute.TargetHttpProxy                   7     16     43.750000
# google.compute.TargetHttpsProxy                  7     14     50.000000
# google.compute.TargetPool                        0      8      0.000000
# google.compute.UrlMap                            0     13      0.000000
# google.container.Cluster                        99    234     42.307692
# google.iam.ServiceAccountKey                    14    130     10.769231
# google.pubsub.Topic                              0     22      0.000000
# rbac.authorization.k8s.io.ClusterRoleBinding     0   1173      0.000000

# %% [markdown]
# ## Grouped by Finding Category

# %%
(
    df.groupby(["category"])
    .agg(
        vuln=pd.NamedAgg(column="count", aggfunc="sum"),
        total=pd.NamedAgg(column="count", aggfunc="count"),
    )
    .assign(vuln_percent=lambda tdf: tdf["vuln"] * 100 / tdf["total"])
)
# Out:
#                                         vuln  total  vuln_percent
# category
# ADMIN_SERVICE_ACCOUNT                      5     58      8.620690
# API_KEY_APIS_UNRESTRICTED                  6     51     11.764706
# API_KEY_APPS_UNRESTRICTED                 15     51     29.411765
# API_KEY_EXISTS                            16     51     31.372549
# API_KEY_NOT_ROTATED                       14     51     27.450980
# AUDIT_CONFIG_NOT_MONITORED                51     51    100.000000
# AUDIT_LOGGING_DISABLED                    52     52    100.000000
# AUTO_BACKUP_DISABLED                       0      3      0.000000
# AUTO_REPAIR_DISABLED                       0     13      0.000000
# AUTO_UPGRADE_DISABLED                      0     13      0.000000
# BUCKET_CMEK_DISABLED                       0     72      0.000000
# BUCKET_IAM_NOT_MONITORED                  51     51    100.000000
# BUCKET_LOGGING_DISABLED                   72     72    100.000000
# BUCKET_POLICY_ONLY_DISABLED               69     72     95.833333
# CLUSTER_ADMIN_ROLE_USED                    0   1173      0.000000
# CLUSTER_LOGGING_DISABLED                   0     13      0.000000
# CLUSTER_MONITORING_DISABLED                0     13      0.000000
# CLUSTER_PRIVATE_GOOGLE_ACCESS_DISABLED    12     13     92.307692
# COMPUTE_PROJECT_WIDE_SSH_KEYS_ALLOWED     33     81     40.740741
# COMPUTE_SECURE_BOOT_DISABLED              16     81     19.753086
# COMPUTE_SERIAL_PORTS_ENABLED               0     81      0.000000
# COS_NOT_USED                               0     13      0.000000
# CUSTOM_ROLE_NOT_MONITORED                 51     51    100.000000
# DEFAULT_NETWORK                           39     42     92.857143
# DEFAULT_SERVICE_ACCOUNT_USED              32     81     39.506173
# DISALLOWED_BQ4G_ENABLED_API                0     51      0.000000
# DISALLOWED_BQ4G_IDENTITY                   0     59      0.000000
# DISK_CMEK_DISABLED                         0     82      0.000000
# DISK_CSEK_DISABLED                         0     82      0.000000
# DNSSEC_DISABLED                            2      2    100.000000
# EGRESS_DENY_RULE_NOT_SET                  39     51     76.470588
# FIREWALL_NOT_MONITORED                    51     51    100.000000
# FIREWALL_RULE_LOGGING_DISABLED           194    264     73.484848
# FLOW_LOGS_DISABLED                      1232   1232    100.000000
# FULL_API_ACCESS                            1     81      1.234568
# HTTP_LOAD_BALANCER                         7      8     87.500000
# IP_ALIAS_DISABLED                          4     13     30.769231
# IP_FORWARDING_ENABLED                      0     81      0.000000
# KMS_PROJECT_HAS_OWNER                      0     51      0.000000
# KMS_ROLE_SEPARATION                        0     58      0.000000
# LEGACY_AUTHORIZATION_ENABLED               0     13      0.000000
# LEGACY_METADATA_ENABLED                    0     13      0.000000
# LEGACY_NETWORK                             0     42      0.000000
# LOCKED_RETENTION_POLICY_NOT_SET            0     72      0.000000
# LOG_NOT_EXPORTED                          51     51    100.000000
# MASTER_AUTHORIZED_NETWORKS_DISABLED       12     13     92.307692
# MFA_NOT_ENFORCED                           1      1    100.000000
# NETWORK_NOT_MONITORED                     51     51    100.000000
# NETWORK_POLICY_DISABLED                   12     13     92.307692
# NODEPOOL_BOOT_CMEK_DISABLED                0     13      0.000000
# NON_ORG_IAM_MEMBER                        10     52     19.230769
# OBJECT_VERSIONING_DISABLED                 0     72      0.000000
# OPEN_CASSANDRA_PORT                        1    264      0.378788
# OPEN_CISCOSECURE_WEBSM_PORT                0    264      0.000000
# OPEN_DIRECTORY_SERVICES_PORT               0    264      0.000000
# OPEN_DNS_PORT                              0    264      0.000000
# OPEN_ELASTICSEARCH_PORT                    0    264      0.000000
# OPEN_FIREWALL                             25    264      9.469697
# OPEN_FTP_PORT                              0    264      0.000000
# OPEN_HTTP_PORT                            13    264      4.924242
# OPEN_LDAP_PORT                             0    264      0.000000
# OPEN_MEMCACHED_PORT                        0    264      0.000000
# OPEN_MONGODB_PORT                          0    264      0.000000
# OPEN_MYSQL_PORT                            1    264      0.378788
# OPEN_NETBIOS_PORT                          0    264      0.000000
# OPEN_ORACLEDB_PORT                         0    264      0.000000
# OPEN_POP3_PORT                             0    264      0.000000
# OPEN_POSTGRESQL_PORT                       0    264      0.000000
# OPEN_RDP_PORT                             38    264     14.393939
# OPEN_REDIS_PORT                            0    264      0.000000
# OPEN_SMTP_PORT                             0    264      0.000000
# OPEN_SSH_PORT                             40    264     15.151515
# OPEN_TELNET_PORT                           0    264      0.000000
# ORG_POLICY_CONFIDENTIAL_VM_POLICY          0     81      0.000000
# ORG_POLICY_LOCATION_RESTRICTION            0   1662      0.000000
# OS_LOGIN_DISABLED                         39     39    100.000000
# OVER_PRIVILEGED_ACCOUNT                   12     13     92.307692
# OVER_PRIVILEGED_SCOPES                    12     13     92.307692
# OVER_PRIVILEGED_SERVICE_ACCOUNT_USER       0     58      0.000000
# OWNER_NOT_MONITORED                       51     51    100.000000
# POD_SECURITY_POLICY_DISABLED              12     13     92.307692
# PRIMITIVE_ROLES_USED                      52     52    100.000000
# PRIVATE_CLUSTER_DISABLED                  12     13     92.307692
# PRIVATE_GOOGLE_ACCESS_DISABLED          1231   1232     99.918831
# PUBLIC_BUCKET_ACL                          1     72      1.388889
# PUBLIC_DATASET                             0      2      0.000000
# PUBLIC_IP_ADDRESS                         31     81     38.271605
# PUBLIC_LOG_BUCKET                          0     72      0.000000
# PUBLIC_SQL_INSTANCE                        0      3      0.000000
# PUBSUB_CMEK_DISABLED                       0     11      0.000000
# REDIS_ROLE_USED_ON_ORG                     0      1      0.000000
# ROUTE_NOT_MONITORED                       51     51    100.000000
# RSASHA1_FOR_SIGNING                        0      2      0.000000
# SERVICE_ACCOUNT_KEY_NOT_ROTATED            7     65     10.769231
# SERVICE_ACCOUNT_ROLE_SEPARATION            0     58      0.000000
# SHIELDED_VM_DISABLED                      17     81     20.987654
# SQL_CMEK_DISABLED                          0      3      0.000000
# SQL_CONTAINED_DATABASE_AUTHENTICATION      0      3      0.000000
# SQL_CROSS_DB_OWNERSHIP_CHAINING            0      3      0.000000
# SQL_INSTANCE_NOT_MONITORED                 2     51      3.921569
# SQL_LOCAL_INFILE                           2      3     66.666667
# SQL_LOG_CHECKPOINTS_DISABLED               1      3     33.333333
# SQL_LOG_CONNECTIONS_DISABLED               1      3     33.333333
# SQL_LOG_DISCONNECTIONS_DISABLED            1      3     33.333333
# SQL_LOG_LOCK_WAITS_DISABLED                1      3     33.333333
# SQL_LOG_MIN_DURATION_STATEMENT_ENABLED     0      3      0.000000
# SQL_LOG_MIN_ERROR_STATEMENT                0      3      0.000000
# SQL_LOG_TEMP_FILES                         1      3     33.333333
# SQL_NO_ROOT_PASSWORD                       0      3      0.000000
# SQL_PUBLIC_IP                              3      3    100.000000
# SQL_WEAK_ROOT_PASSWORD                     0      3      0.000000
# SSL_NOT_ENFORCED                           3      3    100.000000
# UNENROLLED_BQ4G_BCID_IDENTITY              0     59      0.000000
# UNENROLLED_REAUTH_IDENTITY                 0     59      0.000000
# USER_MANAGED_SERVICE_ACCOUNT_KEY           7     65     10.769231
# WEAK_SSL_POLICY                            7      7    100.000000
# WEB_UI_ENABLED                             0     13      0.000000
# WORKLOAD_IDENTITY_DISABLED                11     13     84.615385

# %% [markdown]
# ## Grouped by Resource Type and Finding Category

# %%
(
    df.groupby(["resource_type", "category"])
    .agg(
        vuln=pd.NamedAgg(column="count", aggfunc="sum"),
        total=pd.NamedAgg(column="count", aggfunc="count"),
    )
    .assign(vuln_percent=lambda tdf: tdf["vuln"] * 100 / tdf["total"])
)
# Out:
#                                                                                      vuln  \
# resource_type                                category
# google.cloud.bigquery.Dataset                DISALLOWED_BQ4G_IDENTITY                   0
#                                              ORG_POLICY_LOCATION_RESTRICTION            0
#                                              PUBLIC_DATASET                             0
#                                              UNENROLLED_BQ4G_BCID_IDENTITY              0
#                                              UNENROLLED_REAUTH_IDENTITY                 0
# google.cloud.dns.ManagedZone                 DNSSEC_DISABLED                            2
#                                              RSASHA1_FOR_SIGNING                        0
# google.cloud.resourcemanager.Folder          ADMIN_SERVICE_ACCOUNT                      0
#                                              DISALLOWED_BQ4G_IDENTITY                   0
#                                              KMS_ROLE_SEPARATION                        0
#                                              OVER_PRIVILEGED_SERVICE_ACCOUNT_USER       0
#                                              SERVICE_ACCOUNT_ROLE_SEPARATION            0
#                                              UNENROLLED_BQ4G_BCID_IDENTITY              0
#                                              UNENROLLED_REAUTH_IDENTITY                 0
# google.cloud.resourcemanager.Organization    ADMIN_SERVICE_ACCOUNT                      1
#                                              AUDIT_LOGGING_DISABLED                     1
#                                              KMS_ROLE_SEPARATION                        0
#                                              MFA_NOT_ENFORCED                           1
#                                              NON_ORG_IAM_MEMBER                         1
#                                              OVER_PRIVILEGED_SERVICE_ACCOUNT_USER       0
#                                              PRIMITIVE_ROLES_USED                       1
#                                              REDIS_ROLE_USED_ON_ORG                     0
#                                              SERVICE_ACCOUNT_ROLE_SEPARATION            0
# google.cloud.resourcemanager.Project         ADMIN_SERVICE_ACCOUNT                      4
#                                              API_KEY_APIS_UNRESTRICTED                  6
#                                              API_KEY_APPS_UNRESTRICTED                 15
#                                              API_KEY_EXISTS                            16
#                                              API_KEY_NOT_ROTATED                       14
#                                              AUDIT_CONFIG_NOT_MONITORED                51
#                                              AUDIT_LOGGING_DISABLED                    51
#                                              BUCKET_IAM_NOT_MONITORED                  51
#                                              CUSTOM_ROLE_NOT_MONITORED                 51
#                                              DISALLOWED_BQ4G_ENABLED_API                0
#                                              DISALLOWED_BQ4G_IDENTITY                   0
#                                              EGRESS_DENY_RULE_NOT_SET                  39
#                                              FIREWALL_NOT_MONITORED                    51
#                                              KMS_PROJECT_HAS_OWNER                      0
#                                              KMS_ROLE_SEPARATION                        0
#                                              LOG_NOT_EXPORTED                          51
#                                              NETWORK_NOT_MONITORED                     51
#                                              NON_ORG_IAM_MEMBER                         9
#                                              OVER_PRIVILEGED_SERVICE_ACCOUNT_USER       0
#                                              OWNER_NOT_MONITORED                       51
#                                              PRIMITIVE_ROLES_USED                      51
#                                              ROUTE_NOT_MONITORED                       51
#                                              SERVICE_ACCOUNT_ROLE_SEPARATION            0
#                                              SQL_INSTANCE_NOT_MONITORED                 2
#                                              UNENROLLED_BQ4G_BCID_IDENTITY              0
#                                              UNENROLLED_REAUTH_IDENTITY                 0
# google.cloud.sql.Instance                    AUTO_BACKUP_DISABLED                       0
#                                              ORG_POLICY_LOCATION_RESTRICTION            0
#                                              PUBLIC_SQL_INSTANCE                        0
#                                              SQL_CMEK_DISABLED                          0
#                                              SQL_CONTAINED_DATABASE_AUTHENTICATION      0
#                                              SQL_CROSS_DB_OWNERSHIP_CHAINING            0
#                                              SQL_LOCAL_INFILE                           2
#                                              SQL_LOG_CHECKPOINTS_DISABLED               1
#                                              SQL_LOG_CONNECTIONS_DISABLED               1
#                                              SQL_LOG_DISCONNECTIONS_DISABLED            1
#                                              SQL_LOG_LOCK_WAITS_DISABLED                1
#                                              SQL_LOG_MIN_DURATION_STATEMENT_ENABLED     0
#                                              SQL_LOG_MIN_ERROR_STATEMENT                0
#                                              SQL_LOG_TEMP_FILES                         1
#                                              SQL_NO_ROOT_PASSWORD                       0
#                                              SQL_PUBLIC_IP                              3
#                                              SQL_WEAK_ROOT_PASSWORD                     0
#                                              SSL_NOT_ENFORCED                           3
# google.cloud.storage.Bucket                  BUCKET_CMEK_DISABLED                       0
#                                              BUCKET_LOGGING_DISABLED                   72
#                                              BUCKET_POLICY_ONLY_DISABLED               69
#                                              LOCKED_RETENTION_POLICY_NOT_SET            0
#                                              OBJECT_VERSIONING_DISABLED                 0
#                                              ORG_POLICY_LOCATION_RESTRICTION            0
#                                              PUBLIC_BUCKET_ACL                          1
#                                              PUBLIC_LOG_BUCKET                          0
# google.compute.Address                       ORG_POLICY_LOCATION_RESTRICTION            0
# google.compute.Autoscaler                    ORG_POLICY_LOCATION_RESTRICTION            0
# google.compute.Disk                          DISK_CMEK_DISABLED                         0
#                                              DISK_CSEK_DISABLED                         0
#                                              ORG_POLICY_LOCATION_RESTRICTION            0
# google.compute.Firewall                      FIREWALL_RULE_LOGGING_DISABLED           194
#                                              OPEN_CASSANDRA_PORT                        1
#                                              OPEN_CISCOSECURE_WEBSM_PORT                0
#                                              OPEN_DIRECTORY_SERVICES_PORT               0
#                                              OPEN_DNS_PORT                              0
#                                              OPEN_ELASTICSEARCH_PORT                    0
#                                              OPEN_FIREWALL                             25
#                                              OPEN_FTP_PORT                              0
#                                              OPEN_HTTP_PORT                            13
#                                              OPEN_LDAP_PORT                             0
#                                              OPEN_MEMCACHED_PORT                        0
#                                              OPEN_MONGODB_PORT                          0
#                                              OPEN_MYSQL_PORT                            1
#                                              OPEN_NETBIOS_PORT                          0
#                                              OPEN_ORACLEDB_PORT                         0
#                                              OPEN_POP3_PORT                             0
#                                              OPEN_POSTGRESQL_PORT                       0
#                                              OPEN_RDP_PORT                             38
#                                              OPEN_REDIS_PORT                            0
#                                              OPEN_SMTP_PORT                             0
#                                              OPEN_SSH_PORT                             40
#                                              OPEN_TELNET_PORT                           0
# google.compute.ForwardingRule                ORG_POLICY_LOCATION_RESTRICTION            0
# google.compute.HealthCheck                   ORG_POLICY_LOCATION_RESTRICTION            0
# google.compute.Instance                      COMPUTE_PROJECT_WIDE_SSH_KEYS_ALLOWED     33
#                                              COMPUTE_SECURE_BOOT_DISABLED              16
#                                              COMPUTE_SERIAL_PORTS_ENABLED               0
#                                              DEFAULT_SERVICE_ACCOUNT_USED              32
#                                              FULL_API_ACCESS                            1
#                                              IP_FORWARDING_ENABLED                      0
#                                              ORG_POLICY_CONFIDENTIAL_VM_POLICY          0
#                                              ORG_POLICY_LOCATION_RESTRICTION            0
#                                              PUBLIC_IP_ADDRESS                         31
#                                              SHIELDED_VM_DISABLED                      17
# google.compute.InstanceGroup                 ORG_POLICY_LOCATION_RESTRICTION            0
# google.compute.InstanceGroupManager          ORG_POLICY_LOCATION_RESTRICTION            0
# google.compute.Network                       DEFAULT_NETWORK                           39
#                                              LEGACY_NETWORK                             0
# google.compute.NetworkEndpointGroup          ORG_POLICY_LOCATION_RESTRICTION            0
# google.compute.Project                       OS_LOGIN_DISABLED                         39
# google.compute.RegionBackendService          ORG_POLICY_LOCATION_RESTRICTION            0
# google.compute.Snapshot                      ORG_POLICY_LOCATION_RESTRICTION            0
# google.compute.SslCertificate                ORG_POLICY_LOCATION_RESTRICTION            0
# google.compute.Subnetwork                    FLOW_LOGS_DISABLED                      1232
#                                              ORG_POLICY_LOCATION_RESTRICTION            0
#                                              PRIVATE_GOOGLE_ACCESS_DISABLED          1231
# google.compute.TargetHttpProxy               HTTP_LOAD_BALANCER                         7
#                                              ORG_POLICY_LOCATION_RESTRICTION            0
# google.compute.TargetHttpsProxy              ORG_POLICY_LOCATION_RESTRICTION            0
#                                              WEAK_SSL_POLICY                            7
# google.compute.TargetPool                    ORG_POLICY_LOCATION_RESTRICTION            0
# google.compute.UrlMap                        ORG_POLICY_LOCATION_RESTRICTION            0
# google.container.Cluster                     AUTO_REPAIR_DISABLED                       0
#                                              AUTO_UPGRADE_DISABLED                      0
#                                              CLUSTER_LOGGING_DISABLED                   0
#                                              CLUSTER_MONITORING_DISABLED                0
#                                              CLUSTER_PRIVATE_GOOGLE_ACCESS_DISABLED    12
#                                              COS_NOT_USED                               0
#                                              IP_ALIAS_DISABLED                          4
#                                              LEGACY_AUTHORIZATION_ENABLED               0
#                                              LEGACY_METADATA_ENABLED                    0
#                                              MASTER_AUTHORIZED_NETWORKS_DISABLED       12
#                                              NETWORK_POLICY_DISABLED                   12
#                                              NODEPOOL_BOOT_CMEK_DISABLED                0
#                                              OVER_PRIVILEGED_ACCOUNT                   12
#                                              OVER_PRIVILEGED_SCOPES                    12
#                                              POD_SECURITY_POLICY_DISABLED              12
#                                              PRIVATE_CLUSTER_DISABLED                  12
#                                              WEB_UI_ENABLED                             0
#                                              WORKLOAD_IDENTITY_DISABLED                11
# google.iam.ServiceAccountKey                 SERVICE_ACCOUNT_KEY_NOT_ROTATED            7
#                                              USER_MANAGED_SERVICE_ACCOUNT_KEY           7
# google.pubsub.Topic                          ORG_POLICY_LOCATION_RESTRICTION            0
#                                              PUBSUB_CMEK_DISABLED                       0
# rbac.authorization.k8s.io.ClusterRoleBinding CLUSTER_ADMIN_ROLE_USED                    0
#
#                                                                                      total  \
# resource_type                                category
# google.cloud.bigquery.Dataset                DISALLOWED_BQ4G_IDENTITY                    2
#                                              ORG_POLICY_LOCATION_RESTRICTION             2
#                                              PUBLIC_DATASET                              2
#                                              UNENROLLED_BQ4G_BCID_IDENTITY               2
#                                              UNENROLLED_REAUTH_IDENTITY                  2
# google.cloud.dns.ManagedZone                 DNSSEC_DISABLED                             2
#                                              RSASHA1_FOR_SIGNING                         2
# google.cloud.resourcemanager.Folder          ADMIN_SERVICE_ACCOUNT                       6
#                                              DISALLOWED_BQ4G_IDENTITY                    6
#                                              KMS_ROLE_SEPARATION                         6
#                                              OVER_PRIVILEGED_SERVICE_ACCOUNT_USER        6
#                                              SERVICE_ACCOUNT_ROLE_SEPARATION             6
#                                              UNENROLLED_BQ4G_BCID_IDENTITY               6
#                                              UNENROLLED_REAUTH_IDENTITY                  6
# google.cloud.resourcemanager.Organization    ADMIN_SERVICE_ACCOUNT                       1
#                                              AUDIT_LOGGING_DISABLED                      1
#                                              KMS_ROLE_SEPARATION                         1
#                                              MFA_NOT_ENFORCED                            1
#                                              NON_ORG_IAM_MEMBER                          1
#                                              OVER_PRIVILEGED_SERVICE_ACCOUNT_USER        1
#                                              PRIMITIVE_ROLES_USED                        1
#                                              REDIS_ROLE_USED_ON_ORG                      1
#                                              SERVICE_ACCOUNT_ROLE_SEPARATION             1
# google.cloud.resourcemanager.Project         ADMIN_SERVICE_ACCOUNT                      51
#                                              API_KEY_APIS_UNRESTRICTED                  51
#                                              API_KEY_APPS_UNRESTRICTED                  51
#                                              API_KEY_EXISTS                             51
#                                              API_KEY_NOT_ROTATED                        51
#                                              AUDIT_CONFIG_NOT_MONITORED                 51
#                                              AUDIT_LOGGING_DISABLED                     51
#                                              BUCKET_IAM_NOT_MONITORED                   51
#                                              CUSTOM_ROLE_NOT_MONITORED                  51
#                                              DISALLOWED_BQ4G_ENABLED_API                51
#                                              DISALLOWED_BQ4G_IDENTITY                   51
#                                              EGRESS_DENY_RULE_NOT_SET                   51
#                                              FIREWALL_NOT_MONITORED                     51
#                                              KMS_PROJECT_HAS_OWNER                      51
#                                              KMS_ROLE_SEPARATION                        51
#                                              LOG_NOT_EXPORTED                           51
#                                              NETWORK_NOT_MONITORED                      51
#                                              NON_ORG_IAM_MEMBER                         51
#                                              OVER_PRIVILEGED_SERVICE_ACCOUNT_USER       51
#                                              OWNER_NOT_MONITORED                        51
#                                              PRIMITIVE_ROLES_USED                       51
#                                              ROUTE_NOT_MONITORED                        51
#                                              SERVICE_ACCOUNT_ROLE_SEPARATION            51
#                                              SQL_INSTANCE_NOT_MONITORED                 51
#                                              UNENROLLED_BQ4G_BCID_IDENTITY              51
#                                              UNENROLLED_REAUTH_IDENTITY                 51
# google.cloud.sql.Instance                    AUTO_BACKUP_DISABLED                        3
#                                              ORG_POLICY_LOCATION_RESTRICTION             3
#                                              PUBLIC_SQL_INSTANCE                         3
#                                              SQL_CMEK_DISABLED                           3
#                                              SQL_CONTAINED_DATABASE_AUTHENTICATION       3
#                                              SQL_CROSS_DB_OWNERSHIP_CHAINING             3
#                                              SQL_LOCAL_INFILE                            3
#                                              SQL_LOG_CHECKPOINTS_DISABLED                3
#                                              SQL_LOG_CONNECTIONS_DISABLED                3
#                                              SQL_LOG_DISCONNECTIONS_DISABLED             3
#                                              SQL_LOG_LOCK_WAITS_DISABLED                 3
#                                              SQL_LOG_MIN_DURATION_STATEMENT_ENABLED      3
#                                              SQL_LOG_MIN_ERROR_STATEMENT                 3
#                                              SQL_LOG_TEMP_FILES                          3
#                                              SQL_NO_ROOT_PASSWORD                        3
#                                              SQL_PUBLIC_IP                               3
#                                              SQL_WEAK_ROOT_PASSWORD                      3
#                                              SSL_NOT_ENFORCED                            3
# google.cloud.storage.Bucket                  BUCKET_CMEK_DISABLED                       72
#                                              BUCKET_LOGGING_DISABLED                    72
#                                              BUCKET_POLICY_ONLY_DISABLED                72
#                                              LOCKED_RETENTION_POLICY_NOT_SET            72
#                                              OBJECT_VERSIONING_DISABLED                 72
#                                              ORG_POLICY_LOCATION_RESTRICTION            72
#                                              PUBLIC_BUCKET_ACL                          72
#                                              PUBLIC_LOG_BUCKET                          72
# google.compute.Address                       ORG_POLICY_LOCATION_RESTRICTION            38
# google.compute.Autoscaler                    ORG_POLICY_LOCATION_RESTRICTION             1
# google.compute.Disk                          DISK_CMEK_DISABLED                         82
#                                              DISK_CSEK_DISABLED                         82
#                                              ORG_POLICY_LOCATION_RESTRICTION            82
# google.compute.Firewall                      FIREWALL_RULE_LOGGING_DISABLED            264
#                                              OPEN_CASSANDRA_PORT                       264
#                                              OPEN_CISCOSECURE_WEBSM_PORT               264
#                                              OPEN_DIRECTORY_SERVICES_PORT              264
#                                              OPEN_DNS_PORT                             264
#                                              OPEN_ELASTICSEARCH_PORT                   264
#                                              OPEN_FIREWALL                             264
#                                              OPEN_FTP_PORT                             264
#                                              OPEN_HTTP_PORT                            264
#                                              OPEN_LDAP_PORT                            264
#                                              OPEN_MEMCACHED_PORT                       264
#                                              OPEN_MONGODB_PORT                         264
#                                              OPEN_MYSQL_PORT                           264
#                                              OPEN_NETBIOS_PORT                         264
#                                              OPEN_ORACLEDB_PORT                        264
#                                              OPEN_POP3_PORT                            264
#                                              OPEN_POSTGRESQL_PORT                      264
#                                              OPEN_RDP_PORT                             264
#                                              OPEN_REDIS_PORT                           264
#                                              OPEN_SMTP_PORT                            264
#                                              OPEN_SSH_PORT                             264
#                                              OPEN_TELNET_PORT                          264
# google.compute.ForwardingRule                ORG_POLICY_LOCATION_RESTRICTION             9
# google.compute.HealthCheck                   ORG_POLICY_LOCATION_RESTRICTION            24
# google.compute.Instance                      COMPUTE_PROJECT_WIDE_SSH_KEYS_ALLOWED      81
#                                              COMPUTE_SECURE_BOOT_DISABLED               81
#                                              COMPUTE_SERIAL_PORTS_ENABLED               81
#                                              DEFAULT_SERVICE_ACCOUNT_USED               81
#                                              FULL_API_ACCESS                            81
#                                              IP_FORWARDING_ENABLED                      81
#                                              ORG_POLICY_CONFIDENTIAL_VM_POLICY          81
#                                              ORG_POLICY_LOCATION_RESTRICTION            81
#                                              PUBLIC_IP_ADDRESS                          81
#                                              SHIELDED_VM_DISABLED                       81
# google.compute.InstanceGroup                 ORG_POLICY_LOCATION_RESTRICTION            31
# google.compute.InstanceGroupManager          ORG_POLICY_LOCATION_RESTRICTION            20
# google.compute.Network                       DEFAULT_NETWORK                            42
#                                              LEGACY_NETWORK                             42
# google.compute.NetworkEndpointGroup          ORG_POLICY_LOCATION_RESTRICTION             8
# google.compute.Project                       OS_LOGIN_DISABLED                          39
# google.compute.RegionBackendService          ORG_POLICY_LOCATION_RESTRICTION             2
# google.compute.Snapshot                      ORG_POLICY_LOCATION_RESTRICTION             1
# google.compute.SslCertificate                ORG_POLICY_LOCATION_RESTRICTION             9
# google.compute.Subnetwork                    FLOW_LOGS_DISABLED                       1232
#                                              ORG_POLICY_LOCATION_RESTRICTION          1232
#                                              PRIVATE_GOOGLE_ACCESS_DISABLED           1232
# google.compute.TargetHttpProxy               HTTP_LOAD_BALANCER                          8
#                                              ORG_POLICY_LOCATION_RESTRICTION             8
# google.compute.TargetHttpsProxy              ORG_POLICY_LOCATION_RESTRICTION             7
#                                              WEAK_SSL_POLICY                             7
# google.compute.TargetPool                    ORG_POLICY_LOCATION_RESTRICTION             8
# google.compute.UrlMap                        ORG_POLICY_LOCATION_RESTRICTION            13
# google.container.Cluster                     AUTO_REPAIR_DISABLED                       13
#                                              AUTO_UPGRADE_DISABLED                      13
#                                              CLUSTER_LOGGING_DISABLED                   13
#                                              CLUSTER_MONITORING_DISABLED                13
#                                              CLUSTER_PRIVATE_GOOGLE_ACCESS_DISABLED     13
#                                              COS_NOT_USED                               13
#                                              IP_ALIAS_DISABLED                          13
#                                              LEGACY_AUTHORIZATION_ENABLED               13
#                                              LEGACY_METADATA_ENABLED                    13
#                                              MASTER_AUTHORIZED_NETWORKS_DISABLED        13
#                                              NETWORK_POLICY_DISABLED                    13
#                                              NODEPOOL_BOOT_CMEK_DISABLED                13
#                                              OVER_PRIVILEGED_ACCOUNT                    13
#                                              OVER_PRIVILEGED_SCOPES                     13
#                                              POD_SECURITY_POLICY_DISABLED               13
#                                              PRIVATE_CLUSTER_DISABLED                   13
#                                              WEB_UI_ENABLED                             13
#                                              WORKLOAD_IDENTITY_DISABLED                 13
# google.iam.ServiceAccountKey                 SERVICE_ACCOUNT_KEY_NOT_ROTATED            65
#                                              USER_MANAGED_SERVICE_ACCOUNT_KEY           65
# google.pubsub.Topic                          ORG_POLICY_LOCATION_RESTRICTION            11
#                                              PUBSUB_CMEK_DISABLED                       11
# rbac.authorization.k8s.io.ClusterRoleBinding CLUSTER_ADMIN_ROLE_USED                  1173
#
#                                                                                      vuln_percent
# resource_type                                category
# google.cloud.bigquery.Dataset                DISALLOWED_BQ4G_IDENTITY                    0.000000
#                                              ORG_POLICY_LOCATION_RESTRICTION             0.000000
#                                              PUBLIC_DATASET                              0.000000
#                                              UNENROLLED_BQ4G_BCID_IDENTITY               0.000000
#                                              UNENROLLED_REAUTH_IDENTITY                  0.000000
# google.cloud.dns.ManagedZone                 DNSSEC_DISABLED                           100.000000
#                                              RSASHA1_FOR_SIGNING                         0.000000
# google.cloud.resourcemanager.Folder          ADMIN_SERVICE_ACCOUNT                       0.000000
#                                              DISALLOWED_BQ4G_IDENTITY                    0.000000
#                                              KMS_ROLE_SEPARATION                         0.000000
#                                              OVER_PRIVILEGED_SERVICE_ACCOUNT_USER        0.000000
#                                              SERVICE_ACCOUNT_ROLE_SEPARATION             0.000000
#                                              UNENROLLED_BQ4G_BCID_IDENTITY               0.000000
#                                              UNENROLLED_REAUTH_IDENTITY                  0.000000
# google.cloud.resourcemanager.Organization    ADMIN_SERVICE_ACCOUNT                     100.000000
#                                              AUDIT_LOGGING_DISABLED                    100.000000
#                                              KMS_ROLE_SEPARATION                         0.000000
#                                              MFA_NOT_ENFORCED                          100.000000
#                                              NON_ORG_IAM_MEMBER                        100.000000
#                                              OVER_PRIVILEGED_SERVICE_ACCOUNT_USER        0.000000
#                                              PRIMITIVE_ROLES_USED                      100.000000
#                                              REDIS_ROLE_USED_ON_ORG                      0.000000
#                                              SERVICE_ACCOUNT_ROLE_SEPARATION             0.000000
# google.cloud.resourcemanager.Project         ADMIN_SERVICE_ACCOUNT                       7.843137
#                                              API_KEY_APIS_UNRESTRICTED                  11.764706
#                                              API_KEY_APPS_UNRESTRICTED                  29.411765
#                                              API_KEY_EXISTS                             31.372549
#                                              API_KEY_NOT_ROTATED                        27.450980
#                                              AUDIT_CONFIG_NOT_MONITORED                100.000000
#                                              AUDIT_LOGGING_DISABLED                    100.000000
#                                              BUCKET_IAM_NOT_MONITORED                  100.000000
#                                              CUSTOM_ROLE_NOT_MONITORED                 100.000000
#                                              DISALLOWED_BQ4G_ENABLED_API                 0.000000
#                                              DISALLOWED_BQ4G_IDENTITY                    0.000000
#                                              EGRESS_DENY_RULE_NOT_SET                   76.470588
#                                              FIREWALL_NOT_MONITORED                    100.000000
#                                              KMS_PROJECT_HAS_OWNER                       0.000000
#                                              KMS_ROLE_SEPARATION                         0.000000
#                                              LOG_NOT_EXPORTED                          100.000000
#                                              NETWORK_NOT_MONITORED                     100.000000
#                                              NON_ORG_IAM_MEMBER                         17.647059
#                                              OVER_PRIVILEGED_SERVICE_ACCOUNT_USER        0.000000
#                                              OWNER_NOT_MONITORED                       100.000000
#                                              PRIMITIVE_ROLES_USED                      100.000000
#                                              ROUTE_NOT_MONITORED                       100.000000
#                                              SERVICE_ACCOUNT_ROLE_SEPARATION             0.000000
#                                              SQL_INSTANCE_NOT_MONITORED                  3.921569
#                                              UNENROLLED_BQ4G_BCID_IDENTITY               0.000000
#                                              UNENROLLED_REAUTH_IDENTITY                  0.000000
# google.cloud.sql.Instance                    AUTO_BACKUP_DISABLED                        0.000000
#                                              ORG_POLICY_LOCATION_RESTRICTION             0.000000
#                                              PUBLIC_SQL_INSTANCE                         0.000000
#                                              SQL_CMEK_DISABLED                           0.000000
#                                              SQL_CONTAINED_DATABASE_AUTHENTICATION       0.000000
#                                              SQL_CROSS_DB_OWNERSHIP_CHAINING             0.000000
#                                              SQL_LOCAL_INFILE                           66.666667
#                                              SQL_LOG_CHECKPOINTS_DISABLED               33.333333
#                                              SQL_LOG_CONNECTIONS_DISABLED               33.333333
#                                              SQL_LOG_DISCONNECTIONS_DISABLED            33.333333
#                                              SQL_LOG_LOCK_WAITS_DISABLED                33.333333
#                                              SQL_LOG_MIN_DURATION_STATEMENT_ENABLED      0.000000
#                                              SQL_LOG_MIN_ERROR_STATEMENT                 0.000000
#                                              SQL_LOG_TEMP_FILES                         33.333333
#                                              SQL_NO_ROOT_PASSWORD                        0.000000
#                                              SQL_PUBLIC_IP                             100.000000
#                                              SQL_WEAK_ROOT_PASSWORD                      0.000000
#                                              SSL_NOT_ENFORCED                          100.000000
# google.cloud.storage.Bucket                  BUCKET_CMEK_DISABLED                        0.000000
#                                              BUCKET_LOGGING_DISABLED                   100.000000
#                                              BUCKET_POLICY_ONLY_DISABLED                95.833333
#                                              LOCKED_RETENTION_POLICY_NOT_SET             0.000000
#                                              OBJECT_VERSIONING_DISABLED                  0.000000
#                                              ORG_POLICY_LOCATION_RESTRICTION             0.000000
#                                              PUBLIC_BUCKET_ACL                           1.388889
#                                              PUBLIC_LOG_BUCKET                           0.000000
# google.compute.Address                       ORG_POLICY_LOCATION_RESTRICTION             0.000000
# google.compute.Autoscaler                    ORG_POLICY_LOCATION_RESTRICTION             0.000000
# google.compute.Disk                          DISK_CMEK_DISABLED                          0.000000
#                                              DISK_CSEK_DISABLED                          0.000000
#                                              ORG_POLICY_LOCATION_RESTRICTION             0.000000
# google.compute.Firewall                      FIREWALL_RULE_LOGGING_DISABLED             73.484848
#                                              OPEN_CASSANDRA_PORT                         0.378788
#                                              OPEN_CISCOSECURE_WEBSM_PORT                 0.000000
#                                              OPEN_DIRECTORY_SERVICES_PORT                0.000000
#                                              OPEN_DNS_PORT                               0.000000
#                                              OPEN_ELASTICSEARCH_PORT                     0.000000
#                                              OPEN_FIREWALL                               9.469697
#                                              OPEN_FTP_PORT                               0.000000
#                                              OPEN_HTTP_PORT                              4.924242
#                                              OPEN_LDAP_PORT                              0.000000
#                                              OPEN_MEMCACHED_PORT                         0.000000
#                                              OPEN_MONGODB_PORT                           0.000000
#                                              OPEN_MYSQL_PORT                             0.378788
#                                              OPEN_NETBIOS_PORT                           0.000000
#                                              OPEN_ORACLEDB_PORT                          0.000000
#                                              OPEN_POP3_PORT                              0.000000
#                                              OPEN_POSTGRESQL_PORT                        0.000000
#                                              OPEN_RDP_PORT                              14.393939
#                                              OPEN_REDIS_PORT                             0.000000
#                                              OPEN_SMTP_PORT                              0.000000
#                                              OPEN_SSH_PORT                              15.151515
#                                              OPEN_TELNET_PORT                            0.000000
# google.compute.ForwardingRule                ORG_POLICY_LOCATION_RESTRICTION             0.000000
# google.compute.HealthCheck                   ORG_POLICY_LOCATION_RESTRICTION             0.000000
# google.compute.Instance                      COMPUTE_PROJECT_WIDE_SSH_KEYS_ALLOWED      40.740741
#                                              COMPUTE_SECURE_BOOT_DISABLED               19.753086
#                                              COMPUTE_SERIAL_PORTS_ENABLED                0.000000
#                                              DEFAULT_SERVICE_ACCOUNT_USED               39.506173
#                                              FULL_API_ACCESS                             1.234568
#                                              IP_FORWARDING_ENABLED                       0.000000
#                                              ORG_POLICY_CONFIDENTIAL_VM_POLICY           0.000000
#                                              ORG_POLICY_LOCATION_RESTRICTION             0.000000
#                                              PUBLIC_IP_ADDRESS                          38.271605
#                                              SHIELDED_VM_DISABLED                       20.987654
# google.compute.InstanceGroup                 ORG_POLICY_LOCATION_RESTRICTION             0.000000
# google.compute.InstanceGroupManager          ORG_POLICY_LOCATION_RESTRICTION             0.000000
# google.compute.Network                       DEFAULT_NETWORK                            92.857143
#                                              LEGACY_NETWORK                              0.000000
# google.compute.NetworkEndpointGroup          ORG_POLICY_LOCATION_RESTRICTION             0.000000
# google.compute.Project                       OS_LOGIN_DISABLED                         100.000000
# google.compute.RegionBackendService          ORG_POLICY_LOCATION_RESTRICTION             0.000000
# google.compute.Snapshot                      ORG_POLICY_LOCATION_RESTRICTION             0.000000
# google.compute.SslCertificate                ORG_POLICY_LOCATION_RESTRICTION             0.000000
# google.compute.Subnetwork                    FLOW_LOGS_DISABLED                        100.000000
#                                              ORG_POLICY_LOCATION_RESTRICTION             0.000000
#                                              PRIVATE_GOOGLE_ACCESS_DISABLED             99.918831
# google.compute.TargetHttpProxy               HTTP_LOAD_BALANCER                         87.500000
#                                              ORG_POLICY_LOCATION_RESTRICTION             0.000000
# google.compute.TargetHttpsProxy              ORG_POLICY_LOCATION_RESTRICTION             0.000000
#                                              WEAK_SSL_POLICY                           100.000000
# google.compute.TargetPool                    ORG_POLICY_LOCATION_RESTRICTION             0.000000
# google.compute.UrlMap                        ORG_POLICY_LOCATION_RESTRICTION             0.000000
# google.container.Cluster                     AUTO_REPAIR_DISABLED                        0.000000
#                                              AUTO_UPGRADE_DISABLED                       0.000000
#                                              CLUSTER_LOGGING_DISABLED                    0.000000
#                                              CLUSTER_MONITORING_DISABLED                 0.000000
#                                              CLUSTER_PRIVATE_GOOGLE_ACCESS_DISABLED     92.307692
#                                              COS_NOT_USED                                0.000000
#                                              IP_ALIAS_DISABLED                          30.769231
#                                              LEGACY_AUTHORIZATION_ENABLED                0.000000
#                                              LEGACY_METADATA_ENABLED                     0.000000
#                                              MASTER_AUTHORIZED_NETWORKS_DISABLED        92.307692
#                                              NETWORK_POLICY_DISABLED                    92.307692
#                                              NODEPOOL_BOOT_CMEK_DISABLED                 0.000000
#                                              OVER_PRIVILEGED_ACCOUNT                    92.307692
#                                              OVER_PRIVILEGED_SCOPES                     92.307692
#                                              POD_SECURITY_POLICY_DISABLED               92.307692
#                                              PRIVATE_CLUSTER_DISABLED                   92.307692
#                                              WEB_UI_ENABLED                              0.000000
#                                              WORKLOAD_IDENTITY_DISABLED                 84.615385
# google.iam.ServiceAccountKey                 SERVICE_ACCOUNT_KEY_NOT_ROTATED            10.769231
#                                              USER_MANAGED_SERVICE_ACCOUNT_KEY           10.769231
# google.pubsub.Topic                          ORG_POLICY_LOCATION_RESTRICTION             0.000000
#                                              PUBSUB_CMEK_DISABLED                        0.000000
# rbac.authorization.k8s.io.ClusterRoleBinding CLUSTER_ADMIN_ROLE_USED                     0.000000

# %% [markdown]
# ## Grouped by Project

# %%
(
    df.groupby(["project"])
    .agg(
        vuln=pd.NamedAgg(column="count", aggfunc="sum"),
        total=pd.NamedAgg(column="count", aggfunc="count"),
    )
    .assign(vuln_percent=lambda tdf: tdf["vuln"] * 100 / tdf["total"])
)
# Out:
#                                                               vuln  total  \
# project
#                                                                  5     51
# //cloudresourcemanager.googleapis.com/projects/1017912286515    88    578
# //cloudresourcemanager.googleapis.com/projects/1019916420154    92    269
# //cloudresourcemanager.googleapis.com/projects/1021433544460    89    273
# //cloudresourcemanager.googleapis.com/projects/1070129633700    81    217
# //cloudresourcemanager.googleapis.com/projects/1077948334271    83    227
# //cloudresourcemanager.googleapis.com/projects/1086179641684    83    253
# //cloudresourcemanager.googleapis.com/projects/118316841015     10     26
# //cloudresourcemanager.googleapis.com/projects/130192916715     89    235
# //cloudresourcemanager.googleapis.com/projects/188494990585     83    213
# //cloudresourcemanager.googleapis.com/projects/205898395216     83    220
# //cloudresourcemanager.googleapis.com/projects/216108139135     87    243
# //cloudresourcemanager.googleapis.com/projects/216245613910     87    227
# //cloudresourcemanager.googleapis.com/projects/225465665268     84    267
# //cloudresourcemanager.googleapis.com/projects/259424250065     85    233
# //cloudresourcemanager.googleapis.com/projects/314130770579     90    245
# //cloudresourcemanager.googleapis.com/projects/316965714004    100    272
# //cloudresourcemanager.googleapis.com/projects/350556640222     87    501
# //cloudresourcemanager.googleapis.com/projects/379761789905     10     26
# //cloudresourcemanager.googleapis.com/projects/393504363708     97    294
# //cloudresourcemanager.googleapis.com/projects/410049171019    105    311
# //cloudresourcemanager.googleapis.com/projects/469450300351     10     26
# //cloudresourcemanager.googleapis.com/projects/491846130587    121   1277
# //cloudresourcemanager.googleapis.com/projects/507971936797     83    242
# //cloudresourcemanager.googleapis.com/projects/50972235075      93    355
# //cloudresourcemanager.googleapis.com/projects/523414836526     85    235
# //cloudresourcemanager.googleapis.com/projects/56219393169      11     34
# //cloudresourcemanager.googleapis.com/projects/568344438209     79    207
# //cloudresourcemanager.googleapis.com/projects/605798553038     85    235
# //cloudresourcemanager.googleapis.com/projects/627501189314     10     26
# //cloudresourcemanager.googleapis.com/projects/658279689458     94    244
# //cloudresourcemanager.googleapis.com/projects/664412159370     10     26
# //cloudresourcemanager.googleapis.com/projects/680084556935     10     26
# //cloudresourcemanager.googleapis.com/projects/682734950441     16     52
# //cloudresourcemanager.googleapis.com/projects/68404284703     152   1417
# //cloudresourcemanager.googleapis.com/projects/702532267965    225    569
# //cloudresourcemanager.googleapis.com/projects/705883220659     89    507
# //cloudresourcemanager.googleapis.com/projects/71750814904      86    220
# //cloudresourcemanager.googleapis.com/projects/728945198360     87    265
# //cloudresourcemanager.googleapis.com/projects/750472880964    133    490
# //cloudresourcemanager.googleapis.com/projects/762209195512     14     44
# //cloudresourcemanager.googleapis.com/projects/795110862920     17     48
# //cloudresourcemanager.googleapis.com/projects/79742808973      10     26
# //cloudresourcemanager.googleapis.com/projects/829233264913     10     26
# //cloudresourcemanager.googleapis.com/projects/850819770525     89    235
# //cloudresourcemanager.googleapis.com/projects/891045812741    100    615
# //cloudresourcemanager.googleapis.com/projects/891640704971    106    545
# //cloudresourcemanager.googleapis.com/projects/926236936365     91    289
# //cloudresourcemanager.googleapis.com/projects/93875133545      88    227
# //cloudresourcemanager.googleapis.com/projects/974289724540     99    324
# //cloudresourcemanager.googleapis.com/projects/975997891497     81    215
# //cloudresourcemanager.googleapis.com/projects/991569377383     85    229
#
#                                                               vuln_percent
# project
#                                                                   9.803922
# //cloudresourcemanager.googleapis.com/projects/1017912286515     15.224913
# //cloudresourcemanager.googleapis.com/projects/1019916420154     34.200743
# //cloudresourcemanager.googleapis.com/projects/1021433544460     32.600733
# //cloudresourcemanager.googleapis.com/projects/1070129633700     37.327189
# //cloudresourcemanager.googleapis.com/projects/1077948334271     36.563877
# //cloudresourcemanager.googleapis.com/projects/1086179641684     32.806324
# //cloudresourcemanager.googleapis.com/projects/118316841015      38.461538
# //cloudresourcemanager.googleapis.com/projects/130192916715      37.872340
# //cloudresourcemanager.googleapis.com/projects/188494990585      38.967136
# //cloudresourcemanager.googleapis.com/projects/205898395216      37.727273
# //cloudresourcemanager.googleapis.com/projects/216108139135      35.802469
# //cloudresourcemanager.googleapis.com/projects/216245613910      38.325991
# //cloudresourcemanager.googleapis.com/projects/225465665268      31.460674
# //cloudresourcemanager.googleapis.com/projects/259424250065      36.480687
# //cloudresourcemanager.googleapis.com/projects/314130770579      36.734694
# //cloudresourcemanager.googleapis.com/projects/316965714004      36.764706
# //cloudresourcemanager.googleapis.com/projects/350556640222      17.365269
# //cloudresourcemanager.googleapis.com/projects/379761789905      38.461538
# //cloudresourcemanager.googleapis.com/projects/393504363708      32.993197
# //cloudresourcemanager.googleapis.com/projects/410049171019      33.762058
# //cloudresourcemanager.googleapis.com/projects/469450300351      38.461538
# //cloudresourcemanager.googleapis.com/projects/491846130587       9.475333
# //cloudresourcemanager.googleapis.com/projects/507971936797      34.297521
# //cloudresourcemanager.googleapis.com/projects/50972235075       26.197183
# //cloudresourcemanager.googleapis.com/projects/523414836526      36.170213
# //cloudresourcemanager.googleapis.com/projects/56219393169       32.352941
# //cloudresourcemanager.googleapis.com/projects/568344438209      38.164251
# //cloudresourcemanager.googleapis.com/projects/605798553038      36.170213
# //cloudresourcemanager.googleapis.com/projects/627501189314      38.461538
# //cloudresourcemanager.googleapis.com/projects/658279689458      38.524590
# //cloudresourcemanager.googleapis.com/projects/664412159370      38.461538
# //cloudresourcemanager.googleapis.com/projects/680084556935      38.461538
# //cloudresourcemanager.googleapis.com/projects/682734950441      30.769231
# //cloudresourcemanager.googleapis.com/projects/68404284703       10.726888
# //cloudresourcemanager.googleapis.com/projects/702532267965      39.543058
# //cloudresourcemanager.googleapis.com/projects/705883220659      17.554241
# //cloudresourcemanager.googleapis.com/projects/71750814904       39.090909
# //cloudresourcemanager.googleapis.com/projects/728945198360      32.830189
# //cloudresourcemanager.googleapis.com/projects/750472880964      27.142857
# //cloudresourcemanager.googleapis.com/projects/762209195512      31.818182
# //cloudresourcemanager.googleapis.com/projects/795110862920      35.416667
# //cloudresourcemanager.googleapis.com/projects/79742808973       38.461538
# //cloudresourcemanager.googleapis.com/projects/829233264913      38.461538
# //cloudresourcemanager.googleapis.com/projects/850819770525      37.872340
# //cloudresourcemanager.googleapis.com/projects/891045812741      16.260163
# //cloudresourcemanager.googleapis.com/projects/891640704971      19.449541
# //cloudresourcemanager.googleapis.com/projects/926236936365      31.487889
# //cloudresourcemanager.googleapis.com/projects/93875133545       38.766520
# //cloudresourcemanager.googleapis.com/projects/974289724540      30.555556
# //cloudresourcemanager.googleapis.com/projects/975997891497      37.674419
# //cloudresourcemanager.googleapis.com/projects/991569377383      37.117904

# %% [markdown]
# ## Grouped by Project and Benchmark

# %%
(
    df.explode("benchmarks")
    .groupby(["project", "benchmarks"])
    .agg(
        vuln=pd.NamedAgg(column="count", aggfunc="sum"),
        total=pd.NamedAgg(column="count", aggfunc="count"),
    )
    .assign(vuln_percent=lambda tdf: tdf["vuln"] * 100 / tdf["total"])
)
# Out:
#                                                                               vuln  \
# project                                                      benchmarks
#                                                              CIS 1.0 Level 1     4
#                                                              CIS 1.0 Level 2     0
#                                                              CIS 1.1 Level 1     4
#                                                              CIS 1.1 Level 2     0
#                                                              ISO                 4
#                                                              NIST                4
#                                                              PCI                 4
# //cloudresourcemanager.googleapis.com/projects/1017912286515 CIS 1.0 Level 1    47
#                                                              CIS 1.0 Level 2    33
#                                                              CIS 1.1 Level 1    40
#                                                              CIS 1.1 Level 2     3
#                                                              ISO                41
#                                                              NIST               40
#                                                              PCI                45
# //cloudresourcemanager.googleapis.com/projects/1019916420154 CIS 1.0 Level 1    46
#                                                              CIS 1.0 Level 2    33
#                                                              CIS 1.1 Level 1    46
#                                                              CIS 1.1 Level 2     6
#                                                              ISO                43
#                                                              NIST               42
#                                                              PCI                44
# //cloudresourcemanager.googleapis.com/projects/1021433544460 CIS 1.0 Level 1    43
#                                                              CIS 1.0 Level 2    32
#                                                              CIS 1.1 Level 1    42
#                                                              CIS 1.1 Level 2     5
#                                                              ISO                42
#                                                              NIST               42
#                                                              PCI                44
# //cloudresourcemanager.googleapis.com/projects/1070129633700 CIS 1.0 Level 1    42
#                                                              CIS 1.0 Level 2    32
#                                                              CIS 1.1 Level 1    40
#                                                              CIS 1.1 Level 2     3
#                                                              ISO                39
#                                                              NIST               38
#                                                              PCI                39
# //cloudresourcemanager.googleapis.com/projects/1077948334271 CIS 1.0 Level 1    43
#                                                              CIS 1.0 Level 2    32
#                                                              CIS 1.1 Level 1    40
#                                                              CIS 1.1 Level 2     3
#                                                              ISO                39
#                                                              NIST               38
#                                                              PCI                39
# //cloudresourcemanager.googleapis.com/projects/1086179641684 CIS 1.0 Level 1    41
#                                                              CIS 1.0 Level 2    32
#                                                              CIS 1.1 Level 1    40
#                                                              CIS 1.1 Level 2     3
#                                                              ISO                42
#                                                              NIST               41
#                                                              PCI                43
# //cloudresourcemanager.googleapis.com/projects/118316841015  CIS 1.0 Level 1     9
#                                                              CIS 1.0 Level 2     0
#                                                              CIS 1.1 Level 1     9
#                                                              CIS 1.1 Level 2     0
#                                                              ISO                 3
#                                                              NIST                2
#                                                              PCI                 2
# //cloudresourcemanager.googleapis.com/projects/130192916715  CIS 1.0 Level 1    47
#                                                              CIS 1.0 Level 2    33
#                                                              CIS 1.1 Level 1    43
#                                                              CIS 1.1 Level 2     4
#                                                              ISO                40
#                                                              NIST               39
#                                                              PCI                40
# //cloudresourcemanager.googleapis.com/projects/188494990585  CIS 1.0 Level 1    44
#                                                              CIS 1.0 Level 2    33
#                                                              CIS 1.1 Level 1    43
#                                                              CIS 1.1 Level 2     4
#                                                              ISO                40
#                                                              NIST               39
#                                                              PCI                40
# //cloudresourcemanager.googleapis.com/projects/205898395216  CIS 1.0 Level 1    42
#                                                              CIS 1.0 Level 2    32
#                                                              CIS 1.1 Level 1    42
#                                                              CIS 1.1 Level 2     4
#                                                              ISO                39
#                                                              NIST               39
#                                                              PCI                40
# //cloudresourcemanager.googleapis.com/projects/216108139135  CIS 1.0 Level 1    45
#                                                              CIS 1.0 Level 2    32
#                                                              CIS 1.1 Level 1    40
#                                                              CIS 1.1 Level 2     3
#                                                              ISO                39
#                                                              NIST               38
#                                                              PCI                39
# //cloudresourcemanager.googleapis.com/projects/216245613910  CIS 1.0 Level 1    46
#                                                              CIS 1.0 Level 2    33
#                                                              CIS 1.1 Level 1    43
#                                                              CIS 1.1 Level 2     4
#                                                              ISO                40
#                                                              NIST               39
#                                                              PCI                40
# //cloudresourcemanager.googleapis.com/projects/225465665268  CIS 1.0 Level 1    44
#                                                              CIS 1.0 Level 2    32
#                                                              CIS 1.1 Level 1    44
#                                                              CIS 1.1 Level 2     5
#                                                              ISO                37
#                                                              NIST               37
#                                                              PCI                38
# //cloudresourcemanager.googleapis.com/projects/259424250065  CIS 1.0 Level 1    44
#                                                              CIS 1.0 Level 2    32
#                                                              CIS 1.1 Level 1    40
#                                                              CIS 1.1 Level 2     3
#                                                              ISO                39
#                                                              NIST               38
#                                                              PCI                39
# //cloudresourcemanager.googleapis.com/projects/314130770579  CIS 1.0 Level 1    45
#                                                              CIS 1.0 Level 2    33
#                                                              CIS 1.1 Level 1    45
#                                                              CIS 1.1 Level 2     6
#                                                              ISO                42
#                                                              NIST               42
#                                                              PCI                44
# //cloudresourcemanager.googleapis.com/projects/316965714004  CIS 1.0 Level 1    51
#                                                              CIS 1.0 Level 2    33
#                                                              CIS 1.1 Level 1    50
#                                                              CIS 1.1 Level 2     8
#                                                              ISO                42
#                                                              NIST               43
#                                                              PCI                44
# //cloudresourcemanager.googleapis.com/projects/350556640222  CIS 1.0 Level 1    44
#                                                              CIS 1.0 Level 2    32
#                                                              CIS 1.1 Level 1    42
#                                                              CIS 1.1 Level 2     3
#                                                              ISO                42
#                                                              NIST               41
#                                                              PCI                44
# //cloudresourcemanager.googleapis.com/projects/379761789905  CIS 1.0 Level 1     9
#                                                              CIS 1.0 Level 2     0
#                                                              CIS 1.1 Level 1     9
#                                                              CIS 1.1 Level 2     0
#                                                              ISO                 3
#                                                              NIST                2
#                                                              PCI                 2
# //cloudresourcemanager.googleapis.com/projects/393504363708  CIS 1.0 Level 1    46
#                                                              CIS 1.0 Level 2    32
#                                                              CIS 1.1 Level 1    46
#                                                              CIS 1.1 Level 2     6
#                                                              ISO                41
#                                                              NIST               43
#                                                              PCI                45
# //cloudresourcemanager.googleapis.com/projects/410049171019  CIS 1.0 Level 1    51
#                                                              CIS 1.0 Level 2    33
#                                                              CIS 1.1 Level 1    54
#                                                              CIS 1.1 Level 2     7
#                                                              ISO                42
#                                                              NIST               42
#                                                              PCI                43
# //cloudresourcemanager.googleapis.com/projects/469450300351  CIS 1.0 Level 1     9
#                                                              CIS 1.0 Level 2     0
#                                                              CIS 1.1 Level 1     9
#                                                              CIS 1.1 Level 2     0
#                                                              ISO                 3
#                                                              NIST                2
#                                                              PCI                 2
# //cloudresourcemanager.googleapis.com/projects/491846130587  CIS 1.0 Level 1    69
#                                                              CIS 1.0 Level 2    37
#                                                              CIS 1.1 Level 1    43
#                                                              CIS 1.1 Level 2     4
#                                                              ISO                51
#                                                              NIST               50
#                                                              PCI                64
# //cloudresourcemanager.googleapis.com/projects/507971936797  CIS 1.0 Level 1    42
#                                                              CIS 1.0 Level 2    31
#                                                              CIS 1.1 Level 1    42
#                                                              CIS 1.1 Level 2     4
#                                                              ISO                39
#                                                              NIST               39
#                                                              PCI                40
# //cloudresourcemanager.googleapis.com/projects/50972235075   CIS 1.0 Level 1    44
#                                                              CIS 1.0 Level 2    34
#                                                              CIS 1.1 Level 1    44
#                                                              CIS 1.1 Level 2     7
#                                                              ISO                44
#                                                              NIST               44
#                                                              PCI                46
# //cloudresourcemanager.googleapis.com/projects/523414836526  CIS 1.0 Level 1    44
#                                                              CIS 1.0 Level 2    32
#                                                              CIS 1.1 Level 1    40
#                                                              CIS 1.1 Level 2     3
#                                                              ISO                39
#                                                              NIST               38
#                                                              PCI                39
# //cloudresourcemanager.googleapis.com/projects/56219393169   CIS 1.0 Level 1    10
#                                                              CIS 1.0 Level 2     0
#                                                              CIS 1.1 Level 1     9
#                                                              CIS 1.1 Level 2     0
#                                                              ISO                 3
#                                                              NIST                2
#                                                              PCI                 2
# //cloudresourcemanager.googleapis.com/projects/568344438209  CIS 1.0 Level 1    41
#                                                              CIS 1.0 Level 2    32
#                                                              CIS 1.1 Level 1    40
#                                                              CIS 1.1 Level 2     3
#                                                              ISO                39
#                                                              NIST               38
#                                                              PCI                39
# //cloudresourcemanager.googleapis.com/projects/605798553038  CIS 1.0 Level 1    44
#                                                              CIS 1.0 Level 2    32
#                                                              CIS 1.1 Level 1    40
#                                                              CIS 1.1 Level 2     3
#                                                              ISO                39
#                                                              NIST               38
#                                                              PCI                39
# //cloudresourcemanager.googleapis.com/projects/627501189314  CIS 1.0 Level 1     9
#                                                              CIS 1.0 Level 2     0
#                                                              CIS 1.1 Level 1     9
#                                                              CIS 1.1 Level 2     0
#                                                              ISO                 3
#                                                              NIST                2
#                                                              PCI                 2
# //cloudresourcemanager.googleapis.com/projects/658279689458  CIS 1.0 Level 1    50
#                                                              CIS 1.0 Level 2    33
#                                                              CIS 1.1 Level 1    48
#                                                              CIS 1.1 Level 2     6
#                                                              ISO                40
#                                                              NIST               40
#                                                              PCI                41
# //cloudresourcemanager.googleapis.com/projects/664412159370  CIS 1.0 Level 1     9
#                                                              CIS 1.0 Level 2     0
#                                                              CIS 1.1 Level 1     9
#                                                              CIS 1.1 Level 2     0
#                                                              ISO                 3
#                                                              NIST                2
#                                                              PCI                 2
# //cloudresourcemanager.googleapis.com/projects/680084556935  CIS 1.0 Level 1     9
#                                                              CIS 1.0 Level 2     0
#                                                              CIS 1.1 Level 1     9
#                                                              CIS 1.1 Level 2     0
#                                                              ISO                 3
#                                                              NIST                2
#                                                              PCI                 2
# //cloudresourcemanager.googleapis.com/projects/682734950441  CIS 1.0 Level 1    12
#                                                              CIS 1.0 Level 2     0
#                                                              CIS 1.1 Level 1     9
#                                                              CIS 1.1 Level 2     0
#                                                              ISO                 3
#                                                              NIST                2
#                                                              PCI                 2
# //cloudresourcemanager.googleapis.com/projects/68404284703   CIS 1.0 Level 1    76
#                                                              CIS 1.0 Level 2    37
#                                                              CIS 1.1 Level 1    45
#                                                              CIS 1.1 Level 2     5
#                                                              ISO                56
#                                                              NIST               57
#                                                              PCI                83
# //cloudresourcemanager.googleapis.com/projects/702532267965  CIS 1.0 Level 1   110
#                                                              CIS 1.0 Level 2    95
#                                                              CIS 1.1 Level 1   110
#                                                              CIS 1.1 Level 2     8
#                                                              ISO               107
#                                                              NIST              107
#                                                              PCI               108
# //cloudresourcemanager.googleapis.com/projects/705883220659  CIS 1.0 Level 1    48
#                                                              CIS 1.0 Level 2    33
#                                                              CIS 1.1 Level 1    40
#                                                              CIS 1.1 Level 2     3
#                                                              ISO                42
#                                                              NIST               41
#                                                              PCI                45
# //cloudresourcemanager.googleapis.com/projects/71750814904   CIS 1.0 Level 1    43
#                                                              CIS 1.0 Level 2    31
#                                                              CIS 1.1 Level 1    44
#                                                              CIS 1.1 Level 2     4
#                                                              ISO                38
#                                                              NIST               39
#                                                              PCI                40
# //cloudresourcemanager.googleapis.com/projects/728945198360  CIS 1.0 Level 1    42
#                                                              CIS 1.0 Level 2    32
#                                                              CIS 1.1 Level 1    42
#                                                              CIS 1.1 Level 2     4
#                                                              ISO                41
#                                                              NIST               41
#                                                              PCI                44
# //cloudresourcemanager.googleapis.com/projects/750472880964  CIS 1.0 Level 1    63
#                                                              CIS 1.0 Level 2    33
#                                                              CIS 1.1 Level 1    65
#                                                              CIS 1.1 Level 2    18
#                                                              ISO                45
#                                                              NIST               50
#                                                              PCI                55
# //cloudresourcemanager.googleapis.com/projects/762209195512  CIS 1.0 Level 1    11
#                                                              CIS 1.0 Level 2     0
#                                                              CIS 1.1 Level 1     9
#                                                              CIS 1.1 Level 2     0
#                                                              ISO                 3
#                                                              NIST                2
#                                                              PCI                 2
# //cloudresourcemanager.googleapis.com/projects/795110862920  CIS 1.0 Level 1    14
#                                                              CIS 1.0 Level 2     0
#                                                              CIS 1.1 Level 1    12
#                                                              CIS 1.1 Level 2     0
#                                                              ISO                 3
#                                                              NIST                2
#                                                              PCI                 2
# //cloudresourcemanager.googleapis.com/projects/79742808973   CIS 1.0 Level 1     9
#                                                              CIS 1.0 Level 2     0
#                                                              CIS 1.1 Level 1     9
#                                                              CIS 1.1 Level 2     0
#                                                              ISO                 3
#                                                              NIST                2
#                                                              PCI                 2
# //cloudresourcemanager.googleapis.com/projects/829233264913  CIS 1.0 Level 1     9
#                                                              CIS 1.0 Level 2     0
#                                                              CIS 1.1 Level 1     9
#                                                              CIS 1.1 Level 2     0
#                                                              ISO                 3
#                                                              NIST                2
#                                                              PCI                 2
# //cloudresourcemanager.googleapis.com/projects/850819770525  CIS 1.0 Level 1    47
#                                                              CIS 1.0 Level 2    33
#                                                              CIS 1.1 Level 1    43
#                                                              CIS 1.1 Level 2     4
#                                                              ISO                40
#                                                              NIST               39
#                                                              PCI                40
# //cloudresourcemanager.googleapis.com/projects/891045812741  CIS 1.0 Level 1    48
#                                                              CIS 1.0 Level 2    33
#                                                              CIS 1.1 Level 1    42
#                                                              CIS 1.1 Level 2     4
#                                                              ISO                47
#                                                              NIST               47
#                                                              PCI                54
# //cloudresourcemanager.googleapis.com/projects/891640704971  CIS 1.0 Level 1    54
#                                                              CIS 1.0 Level 2    33
#                                                              CIS 1.1 Level 1    42
#                                                              CIS 1.1 Level 2     4
#                                                              ISO                44
#                                                              NIST               44
#                                                              PCI                50
# //cloudresourcemanager.googleapis.com/projects/926236936365  CIS 1.0 Level 1    44
#                                                              CIS 1.0 Level 2    33
#                                                              CIS 1.1 Level 1    44
#                                                              CIS 1.1 Level 2     5
#                                                              ISO                43
#                                                              NIST               43
#                                                              PCI                45
# //cloudresourcemanager.googleapis.com/projects/93875133545   CIS 1.0 Level 1    47
#                                                              CIS 1.0 Level 2    33
#                                                              CIS 1.1 Level 1    44
#                                                              CIS 1.1 Level 2     4
#                                                              ISO                40
#                                                              NIST               39
#                                                              PCI                40
# //cloudresourcemanager.googleapis.com/projects/974289724540  CIS 1.0 Level 1    48
#                                                              CIS 1.0 Level 2    32
#                                                              CIS 1.1 Level 1    42
#                                                              CIS 1.1 Level 2     5
#                                                              ISO                42
#                                                              NIST               42
#                                                              PCI                44
# //cloudresourcemanager.googleapis.com/projects/975997891497  CIS 1.0 Level 1    42
#                                                              CIS 1.0 Level 2    32
#                                                              CIS 1.1 Level 1    40
#                                                              CIS 1.1 Level 2     3
#                                                              ISO                39
#                                                              NIST               38
#                                                              PCI                39
# //cloudresourcemanager.googleapis.com/projects/991569377383  CIS 1.0 Level 1    45
#                                                              CIS 1.0 Level 2    32
#                                                              CIS 1.1 Level 1    42
#                                                              CIS 1.1 Level 2     3
#                                                              ISO                39
#                                                              NIST               38
#                                                              PCI                39
#
#                                                                               total  \
# project                                                      benchmarks
#                                                              CIS 1.0 Level 1     17
#                                                              CIS 1.0 Level 2     14
#                                                              CIS 1.1 Level 1     17
#                                                              CIS 1.1 Level 2     14
#                                                              ISO                 26
#                                                              NIST                25
#                                                              PCI                 12
# //cloudresourcemanager.googleapis.com/projects/1017912286515 CIS 1.0 Level 1     74
#                                                              CIS 1.0 Level 2    161
#                                                              CIS 1.1 Level 1     64
#                                                              CIS 1.1 Level 2     40
#                                                              ISO                316
#                                                              NIST               318
#                                                              PCI                342
# //cloudresourcemanager.googleapis.com/projects/1019916420154 CIS 1.0 Level 1     57
#                                                              CIS 1.0 Level 2     46
#                                                              CIS 1.1 Level 1     58
#                                                              CIS 1.1 Level 2     19
#                                                              ISO                166
#                                                              NIST               165
#                                                              PCI                170
# //cloudresourcemanager.googleapis.com/projects/1021433544460 CIS 1.0 Level 1     56
#                                                              CIS 1.0 Level 2     46
#                                                              CIS 1.1 Level 1     56
#                                                              CIS 1.1 Level 2     19
#                                                              ISO                169
#                                                              NIST               169
#                                                              PCI                174
# //cloudresourcemanager.googleapis.com/projects/1070129633700 CIS 1.0 Level 1     54
#                                                              CIS 1.0 Level 2     41
#                                                              CIS 1.1 Level 1     53
#                                                              CIS 1.1 Level 2     12
#                                                              ISO                126
#                                                              NIST               125
#                                                              PCI                128
# //cloudresourcemanager.googleapis.com/projects/1077948334271 CIS 1.0 Level 1     59
#                                                              CIS 1.0 Level 2     41
#                                                              CIS 1.1 Level 1     57
#                                                              CIS 1.1 Level 2     12
#                                                              ISO                130
#                                                              NIST               129
#                                                              PCI                132
# //cloudresourcemanager.googleapis.com/projects/1086179641684 CIS 1.0 Level 1     51
#                                                              CIS 1.0 Level 2     45
#                                                              CIS 1.1 Level 1     51
#                                                              CIS 1.1 Level 2     16
#                                                              ISO                164
#                                                              NIST               163
#                                                              PCI                168
# //cloudresourcemanager.googleapis.com/projects/118316841015  CIS 1.0 Level 1     16
#                                                              CIS 1.0 Level 2      3
#                                                              CIS 1.1 Level 1     17
#                                                              CIS 1.1 Level 2      3
#                                                              ISO                  8
#                                                              NIST                 7
#                                                              PCI                  6
# //cloudresourcemanager.googleapis.com/projects/130192916715  CIS 1.0 Level 1     62
#                                                              CIS 1.0 Level 2     41
#                                                              CIS 1.1 Level 1     59
#                                                              CIS 1.1 Level 2     12
#                                                              ISO                134
#                                                              NIST               133
#                                                              PCI                136
# //cloudresourcemanager.googleapis.com/projects/188494990585  CIS 1.0 Level 1     55
#                                                              CIS 1.0 Level 2     41
#                                                              CIS 1.1 Level 1     55
#                                                              CIS 1.1 Level 2     12
#                                                              ISO                122
#                                                              NIST               121
#                                                              PCI                124
# //cloudresourcemanager.googleapis.com/projects/205898395216  CIS 1.0 Level 1     53
#                                                              CIS 1.0 Level 2     42
#                                                              CIS 1.1 Level 1     54
#                                                              CIS 1.1 Level 2     15
#                                                              ISO                123
#                                                              NIST               123
#                                                              PCI                126
# //cloudresourcemanager.googleapis.com/projects/216108139135  CIS 1.0 Level 1     65
#                                                              CIS 1.0 Level 2     41
#                                                              CIS 1.1 Level 1     61
#                                                              CIS 1.1 Level 2     12
#                                                              ISO                138
#                                                              NIST               137
#                                                              PCI                140
# //cloudresourcemanager.googleapis.com/projects/216245613910  CIS 1.0 Level 1     59
#                                                              CIS 1.0 Level 2     41
#                                                              CIS 1.1 Level 1     57
#                                                              CIS 1.1 Level 2     12
#                                                              ISO                130
#                                                              NIST               129
#                                                              PCI                132
# //cloudresourcemanager.googleapis.com/projects/225465665268  CIS 1.0 Level 1     55
#                                                              CIS 1.0 Level 2     46
#                                                              CIS 1.1 Level 1     56
#                                                              CIS 1.1 Level 2     19
#                                                              ISO                165
#                                                              NIST               165
#                                                              PCI                170
# //cloudresourcemanager.googleapis.com/projects/259424250065  CIS 1.0 Level 1     58
#                                                              CIS 1.0 Level 2     41
#                                                              CIS 1.1 Level 1     55
#                                                              CIS 1.1 Level 2     12
#                                                              ISO                134
#                                                              NIST               133
#                                                              PCI                136
# //cloudresourcemanager.googleapis.com/projects/314130770579  CIS 1.0 Level 1     55
#                                                              CIS 1.0 Level 2     44
#                                                              CIS 1.1 Level 1     56
#                                                              CIS 1.1 Level 2     17
#                                                              ISO                144
#                                                              NIST               144
#                                                              PCI                148
# //cloudresourcemanager.googleapis.com/projects/316965714004  CIS 1.0 Level 1     71
#                                                              CIS 1.0 Level 2     43
#                                                              CIS 1.1 Level 1     71
#                                                              CIS 1.1 Level 2     18
#                                                              ISO                134
#                                                              NIST               135
#                                                              PCI                138
# //cloudresourcemanager.googleapis.com/projects/350556640222  CIS 1.0 Level 1     90
#                                                              CIS 1.0 Level 2    155
#                                                              CIS 1.1 Level 1     79
#                                                              CIS 1.1 Level 2     33
#                                                              ISO                217
#                                                              NIST               220
#                                                              PCI                240
# //cloudresourcemanager.googleapis.com/projects/379761789905  CIS 1.0 Level 1     16
#                                                              CIS 1.0 Level 2      3
#                                                              CIS 1.1 Level 1     17
#                                                              CIS 1.1 Level 2      3
#                                                              ISO                  8
#                                                              NIST                 7
#                                                              PCI                  6
# //cloudresourcemanager.googleapis.com/projects/393504363708  CIS 1.0 Level 1     73
#                                                              CIS 1.0 Level 2     46
#                                                              CIS 1.1 Level 1     74
#                                                              CIS 1.1 Level 2     23
#                                                              ISO                154
#                                                              NIST               156
#                                                              PCI                160
# //cloudresourcemanager.googleapis.com/projects/410049171019  CIS 1.0 Level 1     76
#                                                              CIS 1.0 Level 2     44
#                                                              CIS 1.1 Level 1     96
#                                                              CIS 1.1 Level 2     19
#                                                              ISO                164
#                                                              NIST               164
#                                                              PCI                166
# //cloudresourcemanager.googleapis.com/projects/469450300351  CIS 1.0 Level 1     16
#                                                              CIS 1.0 Level 2      3
#                                                              CIS 1.1 Level 1     17
#                                                              CIS 1.1 Level 2      3
#                                                              ISO                  8
#                                                              NIST                 7
#                                                              PCI                  6
# //cloudresourcemanager.googleapis.com/projects/491846130587  CIS 1.0 Level 1    178
#                                                              CIS 1.0 Level 2    458
#                                                              CIS 1.1 Level 1    143
#                                                              CIS 1.1 Level 2     98
#                                                              ISO                490
#                                                              NIST               507
#                                                              PCI                570
# //cloudresourcemanager.googleapis.com/projects/507971936797  CIS 1.0 Level 1     53
#                                                              CIS 1.0 Level 2     44
#                                                              CIS 1.1 Level 1     54
#                                                              CIS 1.1 Level 2     17
#                                                              ISO                144
#                                                              NIST               144
#                                                              PCI                148
# //cloudresourcemanager.googleapis.com/projects/50972235075   CIS 1.0 Level 1     55
#                                                              CIS 1.0 Level 2     54
#                                                              CIS 1.1 Level 1     56
#                                                              CIS 1.1 Level 2     27
#                                                              ISO                249
#                                                              NIST               249
#                                                              PCI                258
# //cloudresourcemanager.googleapis.com/projects/523414836526  CIS 1.0 Level 1     62
#                                                              CIS 1.0 Level 2     41
#                                                              CIS 1.1 Level 1     59
#                                                              CIS 1.1 Level 2     12
#                                                              ISO                134
#                                                              NIST               133
#                                                              PCI                136
# //cloudresourcemanager.googleapis.com/projects/56219393169   CIS 1.0 Level 1     19
#                                                              CIS 1.0 Level 2      3
#                                                              CIS 1.1 Level 1     19
#                                                              CIS 1.1 Level 2      3
#                                                              ISO                 12
# ...
#                                                              CIS 1.1 Level 2     25.000000
#                                                              ISO                 31.967213
#                                                              NIST                31.404959
#                                                              PCI                 31.451613
# //cloudresourcemanager.googleapis.com/projects/605798553038  CIS 1.0 Level 1     73.333333
#                                                              CIS 1.0 Level 2     78.048780
#                                                              CIS 1.1 Level 1     70.175439
#                                                              CIS 1.1 Level 2     25.000000
#                                                              ISO                 29.104478
#                                                              NIST                28.571429
#                                                              PCI                 28.676471
# //cloudresourcemanager.googleapis.com/projects/627501189314  CIS 1.0 Level 1     56.250000
#                                                              CIS 1.0 Level 2      0.000000
#                                                              CIS 1.1 Level 1     52.941176
#                                                              CIS 1.1 Level 2      0.000000
#                                                              ISO                 37.500000
#                                                              NIST                28.571429
#                                                              PCI                 33.333333
# //cloudresourcemanager.googleapis.com/projects/658279689458  CIS 1.0 Level 1     74.626866
#                                                              CIS 1.0 Level 2     78.571429
#                                                              CIS 1.1 Level 1     72.727273
#                                                              CIS 1.1 Level 2     40.000000
#                                                              ISO                 30.534351
#                                                              NIST                30.534351
#                                                              PCI                 30.597015
# //cloudresourcemanager.googleapis.com/projects/664412159370  CIS 1.0 Level 1     56.250000
#                                                              CIS 1.0 Level 2      0.000000
#                                                              CIS 1.1 Level 1     52.941176
#                                                              CIS 1.1 Level 2      0.000000
#                                                              ISO                 37.500000
#                                                              NIST                28.571429
#                                                              PCI                 33.333333
# //cloudresourcemanager.googleapis.com/projects/680084556935  CIS 1.0 Level 1     56.250000
#                                                              CIS 1.0 Level 2      0.000000
#                                                              CIS 1.1 Level 1     52.941176
#                                                              CIS 1.1 Level 2      0.000000
#                                                              ISO                 37.500000
#                                                              NIST                28.571429
#                                                              PCI                 33.333333
# //cloudresourcemanager.googleapis.com/projects/682734950441  CIS 1.0 Level 1     44.444444
#                                                              CIS 1.0 Level 2      0.000000
#                                                              CIS 1.1 Level 1     36.000000
#                                                              CIS 1.1 Level 2      0.000000
#                                                              ISO                 15.000000
#                                                              NIST                10.526316
#                                                              PCI                 11.111111
# //cloudresourcemanager.googleapis.com/projects/68404284703   CIS 1.0 Level 1     41.988950
#                                                              CIS 1.0 Level 2      8.222222
#                                                              CIS 1.1 Level 1     32.374101
#                                                              CIS 1.1 Level 2      4.854369
#                                                              ISO                  8.602151
#                                                              NIST                 8.571429
#                                                              PCI                 11.216216
# //cloudresourcemanager.googleapis.com/projects/702532267965  CIS 1.0 Level 1     82.089552
#                                                              CIS 1.0 Level 2     84.070796
#                                                              CIS 1.1 Level 1     76.923077
#                                                              CIS 1.1 Level 2     25.806452
#                                                              ISO                 35.548173
#                                                              NIST                35.430464
#                                                              PCI                 34.951456
# //cloudresourcemanager.googleapis.com/projects/705883220659  CIS 1.0 Level 1     55.172414
#                                                              CIS 1.0 Level 2     21.019108
#                                                              CIS 1.1 Level 1     51.282051
#                                                              CIS 1.1 Level 2      8.571429
#                                                              ISO                 19.266055
#                                                              NIST                18.468468
#                                                              PCI                 18.750000
# //cloudresourcemanager.googleapis.com/projects/71750814904   CIS 1.0 Level 1     75.438596
#                                                              CIS 1.0 Level 2     75.609756
#                                                              CIS 1.1 Level 1     74.576271
#                                                              CIS 1.1 Level 2     25.000000
#                                                              ISO                 36.538462
#                                                              NIST                37.142857
#                                                              PCI                 37.383178
# //cloudresourcemanager.googleapis.com/projects/728945198360  CIS 1.0 Level 1     79.245283
#                                                              CIS 1.0 Level 2     69.565217
#                                                              CIS 1.1 Level 1     77.777778
#                                                              CIS 1.1 Level 2     21.052632
#                                                              ISO                 24.848485
#                                                              NIST                24.848485
#                                                              PCI                 25.882353
# //cloudresourcemanager.googleapis.com/projects/750472880964  CIS 1.0 Level 1     61.165049
#                                                              CIS 1.0 Level 2     55.000000
#                                                              CIS 1.1 Level 1     61.320755
#                                                              CIS 1.1 Level 2     40.000000
#                                                              ISO                 16.544118
#                                                              NIST                18.050542
#                                                              PCI                 19.230769
# //cloudresourcemanager.googleapis.com/projects/762209195512  CIS 1.0 Level 1     45.833333
#                                                              CIS 1.0 Level 2      0.000000
#                                                              CIS 1.1 Level 1     39.130435
#                                                              CIS 1.1 Level 2      0.000000
#                                                              ISO                 18.750000
#                                                              NIST                13.333333
#                                                              PCI                 14.285714
# //cloudresourcemanager.googleapis.com/projects/795110862920  CIS 1.0 Level 1     50.000000
#                                                              CIS 1.0 Level 2      0.000000
#                                                              CIS 1.1 Level 1     44.444444
#                                                              CIS 1.1 Level 2      0.000000
#                                                              ISO                 18.750000
#                                                              NIST                13.333333
#                                                              PCI                 14.285714
# //cloudresourcemanager.googleapis.com/projects/79742808973   CIS 1.0 Level 1     56.250000
#                                                              CIS 1.0 Level 2      0.000000
#                                                              CIS 1.1 Level 1     52.941176
#                                                              CIS 1.1 Level 2      0.000000
#                                                              ISO                 37.500000
#                                                              NIST                28.571429
#                                                              PCI                 33.333333
# //cloudresourcemanager.googleapis.com/projects/829233264913  CIS 1.0 Level 1     56.250000
#                                                              CIS 1.0 Level 2      0.000000
#                                                              CIS 1.1 Level 1     52.941176
#                                                              CIS 1.1 Level 2      0.000000
#                                                              ISO                 37.500000
#                                                              NIST                28.571429
#                                                              PCI                 33.333333
# //cloudresourcemanager.googleapis.com/projects/850819770525  CIS 1.0 Level 1     78.333333
#                                                              CIS 1.0 Level 2     80.487805
#                                                              CIS 1.1 Level 1     75.438596
#                                                              CIS 1.1 Level 2     33.333333
#                                                              ISO                 29.850746
#                                                              NIST                29.323308
#                                                              PCI                 29.411765
# //cloudresourcemanager.googleapis.com/projects/891045812741  CIS 1.0 Level 1     60.000000
#                                                              CIS 1.0 Level 2     21.019108
#                                                              CIS 1.1 Level 1     59.154930
#                                                              CIS 1.1 Level 2      8.695652
#                                                              ISO                 13.091922
#                                                              NIST                12.983425
#                                                              PCI                 13.953488
# //cloudresourcemanager.googleapis.com/projects/891640704971  CIS 1.0 Level 1     58.064516
#                                                              CIS 1.0 Level 2     22.000000
#                                                              CIS 1.1 Level 1     53.164557
#                                                              CIS 1.1 Level 2     11.111111
#                                                              ISO                 16.058394
#                                                              NIST                15.884477
#                                                              PCI                 16.835017
# //cloudresourcemanager.googleapis.com/projects/926236936365  CIS 1.0 Level 1     80.000000
#                                                              CIS 1.0 Level 2     68.750000
#                                                              CIS 1.1 Level 1     78.571429
#                                                              CIS 1.1 Level 2     23.809524
#                                                              ISO                 23.118280
#                                                              NIST                23.118280
#                                                              PCI                 23.437500
# //cloudresourcemanager.googleapis.com/projects/93875133545   CIS 1.0 Level 1     79.661017
#                                                              CIS 1.0 Level 2     80.487805
#                                                              CIS 1.1 Level 1     77.192982
#                                                              CIS 1.1 Level 2     33.333333
#                                                              ISO                 30.769231
#                                                              NIST                30.232558
#                                                              PCI                 30.303030
# //cloudresourcemanager.googleapis.com/projects/974289724540  CIS 1.0 Level 1     64.000000
#                                                              CIS 1.0 Level 2     69.565217
#                                                              CIS 1.1 Level 1     60.000000
#                                                              CIS 1.1 Level 2     26.315789
#                                                              ISO                 22.105263
#                                                              NIST                22.105263
#                                                              PCI                 22.564103
# //cloudresourcemanager.googleapis.com/projects/975997891497  CIS 1.0 Level 1     80.769231
#                                                              CIS 1.0 Level 2     78.048780
#                                                              CIS 1.1 Level 1     78.431373
#                                                              CIS 1.1 Level 2     25.000000
#                                                              ISO                 30.952381
#                                                              NIST                30.400000
#                                                              PCI                 30.468750
# //cloudresourcemanager.googleapis.com/projects/991569377383  CIS 1.0 Level 1     73.770492
#                                                              CIS 1.0 Level 2     78.048780
#                                                              CIS 1.1 Level 1     71.186441
#                                                              CIS 1.1 Level 2     25.000000
#                                                              ISO                 30.000000
#                                                              NIST                29.457364
#                                                              PCI                 29.545455

# %% [markdown]
# # Scratch

# %%
df.head()
# Out:
#                                                       resource_name  \
# 0  //cloudresourcemanager.googleapis.com/organizations/215365938848
# 1  //cloudresourcemanager.googleapis.com/organizations/215365938848
# 2  //cloudresourcemanager.googleapis.com/organizations/215365938848
# 3  //cloudresourcemanager.googleapis.com/organizations/215365938848
# 4  //cloudresourcemanager.googleapis.com/organizations/215365938848
#
#                                resource_type project owners  \
# 0  google.cloud.resourcemanager.Organization             []
# 1  google.cloud.resourcemanager.Organization             []
# 2  google.cloud.resourcemanager.Organization             []
# 3  google.cloud.resourcemanager.Organization             []
# 4  google.cloud.resourcemanager.Organization             []
#
#                  category severity  \
# 0   ADMIN_SERVICE_ACCOUNT   MEDIUM
# 1  AUDIT_LOGGING_DISABLED      LOW
# 2     KMS_ROLE_SEPARATION   MEDIUM
# 3        MFA_NOT_ENFORCED     HIGH
# 4      NON_ORG_IAM_MEMBER     HIGH
#
#                                            benchmarks  count
# 0                  [CIS 1.0 Level 1, CIS 1.1 Level 1]      1
# 1  [CIS 1.0 Level 1, CIS 1.1 Level 1, PCI, NIST, ISO]      1
# 2       [CIS 1.0 Level 2, CIS 1.1 Level 2, NIST, ISO]      0
# 3  [CIS 1.0 Level 1, CIS 1.1 Level 1, PCI, NIST, ISO]      1
# 4  [CIS 1.0 Level 1, CIS 1.1 Level 1, PCI, NIST, ISO]      1

# %%
df[(df["resource_type"] == "google.compute.Instance") & (df["project"] == "//cloudresourcemanager.googleapis.com/projects/750472880964")][["resource_name", "resource_type", "category", "count"]]
# Out:
#                                                                                              resource_name  \
# 7507  //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/2274806817525822379
# 7508  //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/2274806817525822379
# 7509  //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/2274806817525822379
# 7510  //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/2274806817525822379
# 7511  //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/2274806817525822379
# 7512  //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/2274806817525822379
# 7513  //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/2274806817525822379
# 7514  //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/2274806817525822379
# 7515  //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/2274806817525822379
# 7516  //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/2274806817525822379
# 7517     //compute.googleapis.com/projects/css-firing-range/zones/us-east1-b/instances/9159586517650491703
# 7518     //compute.googleapis.com/projects/css-firing-range/zones/us-east1-b/instances/9159586517650491703
# 7519     //compute.googleapis.com/projects/css-firing-range/zones/us-east1-b/instances/9159586517650491703
# 7520     //compute.googleapis.com/projects/css-firing-range/zones/us-east1-b/instances/9159586517650491703
# 7521     //compute.googleapis.com/projects/css-firing-range/zones/us-east1-b/instances/9159586517650491703
# 7522     //compute.googleapis.com/projects/css-firing-range/zones/us-east1-b/instances/9159586517650491703
# 7523     //compute.googleapis.com/projects/css-firing-range/zones/us-east1-b/instances/9159586517650491703
# 7524     //compute.googleapis.com/projects/css-firing-range/zones/us-east1-b/instances/9159586517650491703
# 7525     //compute.googleapis.com/projects/css-firing-range/zones/us-east1-b/instances/9159586517650491703
# 7526     //compute.googleapis.com/projects/css-firing-range/zones/us-east1-b/instances/9159586517650491703
# 7547  //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/8183355986194215784
# 7548  //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/8183355986194215784
# 7549  //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/8183355986194215784
# 7550  //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/8183355986194215784
# 7551  //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/8183355986194215784
# 7552  //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/8183355986194215784
# 7553  //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/8183355986194215784
# 7554  //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/8183355986194215784
# 7555  //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/8183355986194215784
# 7556  //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/8183355986194215784
# 7627    //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/98572465179736509
# 7628    //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/98572465179736509
# 7629    //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/98572465179736509
# 7630    //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/98572465179736509
# 7631    //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/98572465179736509
# 7632    //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/98572465179736509
# 7633    //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/98572465179736509
# 7634    //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/98572465179736509
# 7635    //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/98572465179736509
# 7636    //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/98572465179736509
# 7807     //compute.googleapis.com/projects/css-firing-range/zones/us-east1-b/instances/8162638318069297188
# 7808     //compute.googleapis.com/projects/css-firing-range/zones/us-east1-b/instances/8162638318069297188
# 7809     //compute.googleapis.com/projects/css-firing-range/zones/us-east1-b/instances/8162638318069297188
# 7810     //compute.googleapis.com/projects/css-firing-range/zones/us-east1-b/instances/8162638318069297188
# 7811     //compute.googleapis.com/projects/css-firing-range/zones/us-east1-b/instances/8162638318069297188
# 7812     //compute.googleapis.com/projects/css-firing-range/zones/us-east1-b/instances/8162638318069297188
# 7813     //compute.googleapis.com/projects/css-firing-range/zones/us-east1-b/instances/8162638318069297188
# 7814     //compute.googleapis.com/projects/css-firing-range/zones/us-east1-b/instances/8162638318069297188
# 7815     //compute.googleapis.com/projects/css-firing-range/zones/us-east1-b/instances/8162638318069297188
# 7816     //compute.googleapis.com/projects/css-firing-range/zones/us-east1-b/instances/8162638318069297188
# 8117     //compute.googleapis.com/projects/css-firing-range/zones/us-east1-b/instances/1346374345708565370
# 8118     //compute.googleapis.com/projects/css-firing-range/zones/us-east1-b/instances/1346374345708565370
# 8119     //compute.googleapis.com/projects/css-firing-range/zones/us-east1-b/instances/1346374345708565370
# 8120     //compute.googleapis.com/projects/css-firing-range/zones/us-east1-b/instances/1346374345708565370
# 8121     //compute.googleapis.com/projects/css-firing-range/zones/us-east1-b/instances/1346374345708565370
# 8122     //compute.googleapis.com/projects/css-firing-range/zones/us-east1-b/instances/1346374345708565370
# 8123     //compute.googleapis.com/projects/css-firing-range/zones/us-east1-b/instances/1346374345708565370
# 8124     //compute.googleapis.com/projects/css-firing-range/zones/us-east1-b/instances/1346374345708565370
# 8125     //compute.googleapis.com/projects/css-firing-range/zones/us-east1-b/instances/1346374345708565370
# 8126     //compute.googleapis.com/projects/css-firing-range/zones/us-east1-b/instances/1346374345708565370
# 8177  //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/5538837466907949502
# 8178  //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/5538837466907949502
# 8179  //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/5538837466907949502
# 8180  //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/5538837466907949502
# 8181  //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/5538837466907949502
# 8182  //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/5538837466907949502
# 8183  //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/5538837466907949502
# 8184  //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/5538837466907949502
# 8185  //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/5538837466907949502
# 8186  //compute.googleapis.com/projects/css-firing-range/zones/us-central1-a/instances/5538837466907949502
#
#                 resource_type                               category  count
# 7507  google.compute.Instance  COMPUTE_PROJECT_WIDE_SSH_KEYS_ALLOWED      1
# 7508  google.compute.Instance           COMPUTE_SECURE_BOOT_DISABLED      0
# 7509  google.compute.Instance           COMPUTE_SERIAL_PORTS_ENABLED      0
# 7510  google.compute.Instance           DEFAULT_SERVICE_ACCOUNT_USED      1
# 7511  google.compute.Instance                        FULL_API_ACCESS      0
# 7512  google.compute.Instance                  IP_FORWARDING_ENABLED      0
# 7513  google.compute.Instance      ORG_POLICY_CONFIDENTIAL_VM_POLICY      0
# 7514  google.compute.Instance        ORG_POLICY_LOCATION_RESTRICTION      0
# 7515  google.compute.Instance                      PUBLIC_IP_ADDRESS      1
# 7516  google.compute.Instance                   SHIELDED_VM_DISABLED      1
# 7517  google.compute.Instance  COMPUTE_PROJECT_WIDE_SSH_KEYS_ALLOWED      1
# 7518  google.compute.Instance           COMPUTE_SECURE_BOOT_DISABLED      0
# 7519  google.compute.Instance           COMPUTE_SERIAL_PORTS_ENABLED      0
# 7520  google.compute.Instance           DEFAULT_SERVICE_ACCOUNT_USED      1
# 7521  google.compute.Instance                        FULL_API_ACCESS      0
# 7522  google.compute.Instance                  IP_FORWARDING_ENABLED      0
# 7523  google.compute.Instance      ORG_POLICY_CONFIDENTIAL_VM_POLICY      0
# 7524  google.compute.Instance        ORG_POLICY_LOCATION_RESTRICTION      0
# 7525  google.compute.Instance                      PUBLIC_IP_ADDRESS      1
# 7526  google.compute.Instance                   SHIELDED_VM_DISABLED      1
# 7547  google.compute.Instance  COMPUTE_PROJECT_WIDE_SSH_KEYS_ALLOWED      1
# 7548  google.compute.Instance           COMPUTE_SECURE_BOOT_DISABLED      0
# 7549  google.compute.Instance           COMPUTE_SERIAL_PORTS_ENABLED      0
# 7550  google.compute.Instance           DEFAULT_SERVICE_ACCOUNT_USED      1
# 7551  google.compute.Instance                        FULL_API_ACCESS      0
# 7552  google.compute.Instance                  IP_FORWARDING_ENABLED      0
# 7553  google.compute.Instance      ORG_POLICY_CONFIDENTIAL_VM_POLICY      0
# 7554  google.compute.Instance        ORG_POLICY_LOCATION_RESTRICTION      0
# 7555  google.compute.Instance                      PUBLIC_IP_ADDRESS      1
# 7556  google.compute.Instance                   SHIELDED_VM_DISABLED      1
# 7627  google.compute.Instance  COMPUTE_PROJECT_WIDE_SSH_KEYS_ALLOWED      1
# 7628  google.compute.Instance           COMPUTE_SECURE_BOOT_DISABLED      0
# 7629  google.compute.Instance           COMPUTE_SERIAL_PORTS_ENABLED      0
# 7630  google.compute.Instance           DEFAULT_SERVICE_ACCOUNT_USED      1
# 7631  google.compute.Instance                        FULL_API_ACCESS      0
# 7632  google.compute.Instance                  IP_FORWARDING_ENABLED      0
# 7633  google.compute.Instance      ORG_POLICY_CONFIDENTIAL_VM_POLICY      0
# 7634  google.compute.Instance        ORG_POLICY_LOCATION_RESTRICTION      0
# 7635  google.compute.Instance                      PUBLIC_IP_ADDRESS      1
# 7636  google.compute.Instance                   SHIELDED_VM_DISABLED      1
# 7807  google.compute.Instance  COMPUTE_PROJECT_WIDE_SSH_KEYS_ALLOWED      1
# 7808  google.compute.Instance           COMPUTE_SECURE_BOOT_DISABLED      0
# 7809  google.compute.Instance           COMPUTE_SERIAL_PORTS_ENABLED      0
# 7810  google.compute.Instance           DEFAULT_SERVICE_ACCOUNT_USED      1
# 7811  google.compute.Instance                        FULL_API_ACCESS      0
# 7812  google.compute.Instance                  IP_FORWARDING_ENABLED      0
# 7813  google.compute.Instance      ORG_POLICY_CONFIDENTIAL_VM_POLICY      0
# 7814  google.compute.Instance        ORG_POLICY_LOCATION_RESTRICTION      0
# 7815  google.compute.Instance                      PUBLIC_IP_ADDRESS      1
# 7816  google.compute.Instance                   SHIELDED_VM_DISABLED      1
# 8117  google.compute.Instance  COMPUTE_PROJECT_WIDE_SSH_KEYS_ALLOWED      1
# 8118  google.compute.Instance           COMPUTE_SECURE_BOOT_DISABLED      0
# 8119  google.compute.Instance           COMPUTE_SERIAL_PORTS_ENABLED      0
# 8120  google.compute.Instance           DEFAULT_SERVICE_ACCOUNT_USED      1
# 8121  google.compute.Instance                        FULL_API_ACCESS      0
# 8122  google.compute.Instance                  IP_FORWARDING_ENABLED      0
# 8123  google.compute.Instance      ORG_POLICY_CONFIDENTIAL_VM_POLICY      0
# 8124  google.compute.Instance        ORG_POLICY_LOCATION_RESTRICTION      0
# 8125  google.compute.Instance                      PUBLIC_IP_ADDRESS      1
# 8126  google.compute.Instance                   SHIELDED_VM_DISABLED      1
# 8177  google.compute.Instance  COMPUTE_PROJECT_WIDE_SSH_KEYS_ALLOWED      1
# 8178  google.compute.Instance           COMPUTE_SECURE_BOOT_DISABLED      0
# 8179  google.compute.Instance           COMPUTE_SERIAL_PORTS_ENABLED      0
# 8180  google.compute.Instance           DEFAULT_SERVICE_ACCOUNT_USED      1
# 8181  google.compute.Instance                        FULL_API_ACCESS      0
# 8182  google.compute.Instance                  IP_FORWARDING_ENABLED      0
# 8183  google.compute.Instance      ORG_POLICY_CONFIDENTIAL_VM_POLICY      0
# 8184  google.compute.Instance        ORG_POLICY_LOCATION_RESTRICTION      0
# 8185  google.compute.Instance                      PUBLIC_IP_ADDRESS      1
# 8186  google.compute.Instance                   SHIELDED_VM_DISABLED      1
