# %% [markdown]
# # Setup

# %%
import json

import pandas as pd
from google.cloud import securitycenter_v1
from tqdm import tqdm

pd.set_option("display.max_rows", 1000)
pd.set_option("display.max_colwidth", None)

# %% [markdown]
# # Functions

# %%
scc_client = securitycenter_v1.SecurityCenterClient()


def get_finding_configs():
    with open("finding_configs.json", "r") as fp:
        return json.load(fp)


def get_findings(org_id):
    resp = scc_client.list_findings(
        securitycenter_v1.ListFindingsRequest(
            parent=f"organizations/{org_id}/sources/-",
            page_size=1000,
        )
    )
    return tqdm(resp, total=resp.total_size, unit="findings", desc="Loading Findings")


def get_assets(org_id):
    resp = scc_client.list_assets(
        securitycenter_v1.ListAssetsRequest(
            parent=f"organizations/{org_id}",
            page_size=1000,
        )
    )
    return tqdm(resp, total=resp.total_size, unit="assets", desc="Loading Assets")


def compute_verdicts(assets, findings, finding_configs):
    susceptible_category_map = {}
    for finding_config in finding_configs:
        for resource_type in finding_config["resource_types"]:
            susceptible_category_map.setdefault(resource_type, []).append(
                finding_config["finding_type"]
            )

    finding_type_compliance_map = {}
    for finding_config in finding_configs:
        for compliance in finding_config["compliance_metadata"]:
            finding_type_compliance_map.setdefault(
                finding_config["finding_type"], []
            ).append(compliance)

    vulnerabilities = {
        (f.finding.resource_name, f.finding.category)
        for f in findings
        if f.finding.state == securitycenter_v1.Finding.State.ACTIVE
    }

    return pd.DataFrame(
        [
            {
                "resource_name": asset.asset.security_center_properties.resource_name,
                "resource_type": asset.asset.security_center_properties.resource_type,
                "finding_type": finding_type,
                "verdict": (
                    "positive"
                    if (
                        asset.asset.security_center_properties.resource_name,
                        finding_type,
                    )
                    in vulnerabilities
                    else "negative"
                ),
                "project": asset.asset.security_center_properties.resource_project,
                "benchmarks": finding_type_compliance_map.get(finding_type, []),
            }
            for asset in assets
            for finding_type in susceptible_category_map.get(
                asset.asset.security_center_properties.resource_type, []
            )
        ]
    )

# %% [markdown]
# # Load Findings and Assets

# %%
org_id = "129624834409"
findings = list(get_findings(org_id))
assets = list(get_assets(org_id))
# Out:
# Loading Findings: 100%|██████████| 22693/22693 [00:33<00:00, 669.71findings/s]
# Loading Assets: 100%|██████████| 6794/6794 [00:17<00:00, 387.63assets/s]

# %%
finding_configs = get_finding_configs()
vdf = compute_verdicts(assets, findings, finding_configs)

# %% [markdown]
# # Verdicts

# %%
vdf
# Out:
#                                                                                                                           resource_name  \
# 0                                                                      //cloudresourcemanager.googleapis.com/organizations/129624834409
# 1                                                                      //cloudresourcemanager.googleapis.com/organizations/129624834409
# 2                                                                      //cloudresourcemanager.googleapis.com/organizations/129624834409
# 3                                                                      //cloudresourcemanager.googleapis.com/organizations/129624834409
# 4                                                                      //cloudresourcemanager.googleapis.com/organizations/129624834409
# ...                                                                                                                                 ...
# 17959                              //compute.googleapis.com/projects/kleon-sandbox/regions/us-east1/backendServices/7021574685558114040
# 17960                         //compute.googleapis.com/projects/weak-policy-243021/regions/us-west1/backendServices/3311081193619846270
# 17961                                       //compute.googleapis.com/projects/csek-243518/regions/us-central1/disks/3365701890509221548
# 17962                                          //dataproc.googleapis.com/projects/csek-243518/regions/us-central1/clusters/cluster-f95b
# 17963  //dataflow.googleapis.com/projects/csam-green-test-project-0/locations/us-central1/jobs/2019-12-20_22_31_10-14284321079480391809
#
#                                    resource_type  \
# 0      google.cloud.resourcemanager.Organization
# 1      google.cloud.resourcemanager.Organization
# 2      google.cloud.resourcemanager.Organization
# 3      google.cloud.resourcemanager.Organization
# 4      google.cloud.resourcemanager.Organization
# ...                                          ...
# 17959        google.compute.RegionBackendService
# 17960        google.compute.RegionBackendService
# 17961                  google.compute.RegionDisk
# 17962                    google.dataproc.Cluster
# 17963                        google.dataflow.Job
#
#                           finding_type   verdict  \
# 0                ADMIN_SERVICE_ACCOUNT  positive
# 1               AUDIT_LOGGING_DISABLED  positive
# 2                  KMS_ROLE_SEPARATION  positive
# 3                     MFA_NOT_ENFORCED  positive
# 4                   NON_ORG_IAM_MEMBER  positive
# ...                                ...       ...
# 17959  ORG_POLICY_LOCATION_RESTRICTION  negative
# 17960  ORG_POLICY_LOCATION_RESTRICTION  negative
# 17961  ORG_POLICY_LOCATION_RESTRICTION  negative
# 17962  ORG_POLICY_LOCATION_RESTRICTION  negative
# 17963  ORG_POLICY_LOCATION_RESTRICTION  negative
#
#                                                             project  \
# 0
# 1
# 2
# 3
# 4
# ...                                                             ...
# 17959   //cloudresourcemanager.googleapis.com/projects/335767247403
# 17960    //cloudresourcemanager.googleapis.com/projects/93853049618
# 17961  //cloudresourcemanager.googleapis.com/projects/1037068353870
# 17962  //cloudresourcemanager.googleapis.com/projects/1037068353870
# 17963   //cloudresourcemanager.googleapis.com/projects/897981163389
#
#                                                benchmarks
# 0                      [CIS 1.0 Level 1, CIS 1.1 Level 1]
# 1      [CIS 1.0 Level 1, CIS 1.1 Level 1, PCI, NIST, ISO]
# 2           [CIS 1.0 Level 2, CIS 1.1 Level 2, NIST, ISO]
# 3      [CIS 1.0 Level 1, CIS 1.1 Level 1, PCI, NIST, ISO]
# 4      [CIS 1.0 Level 1, CIS 1.1 Level 1, PCI, NIST, ISO]
# ...                                                   ...
# 17959                                                  []
# 17960                                                  []
# 17961                                                  []
# 17962                                                  []
# 17963                                                  []
#
# [17964 rows x 6 columns]

# %% [markdown]
# # Compliance Coverage

# %% [markdown]
# ## By Benchmark

# %%
benchmarks = {
    benchmark
    for finding_config in finding_configs
    for benchmark in finding_config["compliance_metadata"]
}
benchmarks
# Out:
# {'CIS 1.0 Level 1',
#  'CIS 1.0 Level 2',
#  'CIS 1.1 Level 1',
#  'CIS 1.1 Level 2',
#  'ISO',
#  'NIST',
#  'PCI'}

# %%
rows = []
for benchmark in benchmarks:
    tdf = vdf[vdf["benchmarks"].apply(lambda b: benchmark in b)]
    rows.append(
        {
            "benchmark": benchmark,
            "positive": len(tdf[tdf["verdict"] == "positive"]),
            "total": len(tdf),
        }
    )
tdf = pd.DataFrame(rows)
tdf = tdf.assign(vuln_percent=tdf["positive"] * 100 / tdf["total"])
tdf = tdf.set_index("benchmark").sort_index()
tdf
# Out:
#                  positive  total  vuln_percent
# benchmark
# CIS 1.0 Level 1      1197   2463     48.599269
# CIS 1.0 Level 2       650   3181     20.433826
# CIS 1.1 Level 1      1088   2590     42.007722
# CIS 1.1 Level 2       208   1462     14.227086
# ISO                  1657  11402     14.532538
# NIST                 1665  11433     14.563107
# PCI                  2065  12020     17.179700

# %% [markdown]
# ## Filtered by a Project

# %%
rows = []
for benchmark in benchmarks:
    tdf = vdf[
        (vdf["benchmarks"].apply(lambda b: benchmark in b))
        & (
            vdf["project"]
            == "//cloudresourcemanager.googleapis.com/projects/1037068353870"
        )
    ]
    rows.append(
        {
            "benchmark": benchmark,
            "positive": len(tdf[tdf["verdict"] == "positive"]),
            "total": len(tdf),
        }
    )
tdf = pd.DataFrame(rows)
tdf = tdf.assign(vuln_percent=tdf["positive"] * 100 / tdf["total"])
tdf = tdf.set_index("benchmark").sort_index()
tdf
# Out:
#                  positive  total  vuln_percent
# benchmark
# CIS 1.0 Level 1        52     90     57.777778
# CIS 1.0 Level 2        30     45     66.666667
# CIS 1.1 Level 1        51    100     51.000000
# CIS 1.1 Level 2        11     25     44.000000
# ISO                    44    155     28.387097
# NIST                   39    149     26.174497
# PCI                    48    160     30.000000

# %% [markdown]
# ## By Finding Type

# %%
tdf = vdf[["finding_type", "verdict"]].pivot_table(
    index="finding_type", columns="verdict", aggfunc="size", fill_value=0
)
tdf = tdf.assign(total=tdf.sum(axis="columns"))
tdf = tdf.drop(columns=["negative"])
tdf = tdf.assign(vuln_percent=tdf["positive"] * 100 / tdf["total"])
tdf
# Out:
# verdict                                 positive  total  vuln_percent
# finding_type
# ADMIN_SERVICE_ACCOUNT                         13     54     24.074074
# API_KEY_APIS_UNRESTRICTED                      7     41     17.073171
# API_KEY_APPS_UNRESTRICTED                      3     41      7.317073
# API_KEY_EXISTS                                 7     41     17.073171
# API_KEY_NOT_ROTATED                            7     41     17.073171
# AUDIT_CONFIG_NOT_MONITORED                    38     41     92.682927
# AUDIT_LOGGING_DISABLED                        37     42     88.095238
# AUTO_BACKUP_DISABLED                           1     22      4.545455
# AUTO_REPAIR_DISABLED                           4     16     25.000000
# AUTO_UPGRADE_DISABLED                          5     16     31.250000
# BUCKET_CMEK_DISABLED                          51     56     91.071429
# BUCKET_IAM_NOT_MONITORED                      37     41     90.243902
# BUCKET_LOGGING_DISABLED                       53     56     94.642857
# BUCKET_POLICY_ONLY_DISABLED                   34     56     60.714286
# CLUSTER_ADMIN_ROLE_USED                        0   1306      0.000000
# CLUSTER_LOGGING_DISABLED                       2     16     12.500000
# CLUSTER_MONITORING_DISABLED                    1     16      6.250000
# CLUSTER_PRIVATE_GOOGLE_ACCESS_DISABLED        13     16     81.250000
# COMPUTE_PROJECT_WIDE_SSH_KEYS_ALLOWED         33    102     32.352941
# COMPUTE_SECURE_BOOT_DISABLED                  14    102     13.725490
# COMPUTE_SERIAL_PORTS_ENABLED                   1    102      0.980392
# COS_NOT_USED                                   0     16      0.000000
# CUSTOM_ROLE_NOT_MONITORED                     38     41     92.682927
# DEFAULT_NETWORK                               23     32     71.875000
# DEFAULT_SERVICE_ACCOUNT_USED                  32    102     31.372549
# DISALLOWED_BQ4G_ENABLED_API                    0     41      0.000000
# DISALLOWED_BQ4G_IDENTITY                       0     67      0.000000
# DISK_CMEK_DISABLED                             0    115      0.000000
# DISK_CSEK_DISABLED                             1    115      0.869565
# DNSSEC_DISABLED                                0      5      0.000000
# EGRESS_DENY_RULE_NOT_SET                      22     41     53.658537
# FIREWALL_NOT_MONITORED                        38     41     92.682927
# FIREWALL_RULE_LOGGING_DISABLED               401    470     85.319149
# FLOW_LOGS_DISABLED                           526    639     82.316119
# FULL_API_ACCESS                                2    102      1.960784
# HTTP_LOAD_BALANCER                             2      5     40.000000
# IP_ALIAS_DISABLED                              6     16     37.500000
# IP_FORWARDING_ENABLED                          0    102      0.000000
# KMS_KEY_NOT_ROTATED                            4     24     16.666667
# KMS_PROJECT_HAS_OWNER                          5     41     12.195122
# KMS_PUBLIC_KEY                                 2     38      5.263158
# KMS_ROLE_SEPARATION                            5     54      9.259259
# LEGACY_AUTHORIZATION_ENABLED                   1     16      6.250000
# LEGACY_METADATA_ENABLED                        1     16      6.250000
# LEGACY_NETWORK                                 1     32      3.125000
# LOCKED_RETENTION_POLICY_NOT_SET                4     56      7.142857
# LOG_NOT_EXPORTED                               0     41      0.000000
# MASTER_AUTHORIZED_NETWORKS_DISABLED           16     16    100.000000
# MFA_NOT_ENFORCED                               1      1    100.000000
# NETWORK_NOT_MONITORED                         38     41     92.682927
# NETWORK_POLICY_DISABLED                       16     16    100.000000
# NODEPOOL_BOOT_CMEK_DISABLED                    0     16      0.000000
# NON_ORG_IAM_MEMBER                             9     42     21.428571
# OBJECT_VERSIONING_DISABLED                     4     56      7.142857
# OPEN_CASSANDRA_PORT                           23    470      4.893617
# OPEN_CISCOSECURE_WEBSM_PORT                   23    470      4.893617
# OPEN_DIRECTORY_SERVICES_PORT                  25    470      5.319149
# OPEN_DNS_PORT                                 25    470      5.319149
# OPEN_ELASTICSEARCH_PORT                       23    470      4.893617
# OPEN_FIREWALL                                298    470     63.404255
# OPEN_FTP_PORT                                 23    470      4.893617
# OPEN_HTTP_PORT                                25    470      5.319149
# OPEN_LDAP_PORT                                25    470      5.319149
# OPEN_MEMCACHED_PORT                           25    470      5.319149
# OPEN_MONGODB_PORT                             23    470      4.893617
# OPEN_MYSQL_PORT                               23    470      4.893617
# OPEN_NETBIOS_PORT                             25    470      5.319149
# OPEN_ORACLEDB_PORT                            25    470      5.319149
# OPEN_POP3_PORT                                23    470      4.893617
# OPEN_POSTGRESQL_PORT                          25    470      5.319149
# OPEN_RDP_PORT                                 47    470     10.000000
# OPEN_REDIS_PORT                               23    470      4.893617
# OPEN_SMTP_PORT                                25    470      5.319149
# OPEN_SSH_PORT                                 49    470     10.425532
# OPEN_TELNET_PORT                              25    470      5.319149
# ORG_POLICY_CONFIDENTIAL_VM_POLICY              0    102      0.000000
# ORG_POLICY_LOCATION_RESTRICTION              101   1240      8.145161
# OS_LOGIN_DISABLED                             25     29     86.206897
# OVER_PRIVILEGED_ACCOUNT                       14     16     87.500000
# OVER_PRIVILEGED_SCOPES                        14     16     87.500000
# OVER_PRIVILEGED_SERVICE_ACCOUNT_USER           9     54     16.666667
# OWNER_NOT_MONITORED                           38     41     92.682927
# POD_SECURITY_POLICY_DISABLED                  16     16    100.000000
# PRIMITIVE_ROLES_USED                          38     42     90.476190
# PRIVATE_CLUSTER_DISABLED                      16     16    100.000000
# PRIVATE_GOOGLE_ACCESS_DISABLED               522    639     81.690141
# PUBLIC_BUCKET_ACL                              2     56      3.571429
# PUBLIC_COMPUTE_IMAGE                           1      1    100.000000
# PUBLIC_DATASET                                 2     14     14.285714
# PUBLIC_IP_ADDRESS                             33    102     32.352941
# PUBLIC_LOG_BUCKET                              0     56      0.000000
# PUBLIC_SQL_INSTANCE                            2     22      9.090909
# PUBSUB_CMEK_DISABLED                           0     18      0.000000
# REDIS_ROLE_USED_ON_ORG                         1      1    100.000000
# ROUTE_NOT_MONITORED                           38     41     92.682927
# RSASHA1_FOR_SIGNING                            0      5      0.000000
# SERVICE_ACCOUNT_KEY_NOT_ROTATED               18     81     22.222222
# SERVICE_ACCOUNT_ROLE_SEPARATION                5     54      9.259259
# SHIELDED_VM_DISABLED                          21    102     20.588235
# SQL_CMEK_DISABLED                              0     22      0.000000
# SQL_CONTAINED_DATABASE_AUTHENTICATION          3     22     13.636364
# SQL_CROSS_DB_OWNERSHIP_CHAINING                3     22     13.636364
# SQL_INSTANCE_NOT_MONITORED                     5     41     12.195122
# SQL_LOCAL_INFILE                              11     22     50.000000
# SQL_LOG_CHECKPOINTS_DISABLED                   4     22     18.181818
# SQL_LOG_CONNECTIONS_DISABLED                   4     22     18.181818
# SQL_LOG_DISCONNECTIONS_DISABLED                4     22     18.181818
# SQL_LOG_LOCK_WAITS_DISABLED                    4     22     18.181818
# SQL_LOG_MIN_DURATION_STATEMENT_ENABLED         0     22      0.000000
# SQL_LOG_MIN_ERROR_STATEMENT                    0     22      0.000000
# SQL_LOG_TEMP_FILES                             4     22     18.181818
# SQL_NO_ROOT_PASSWORD                           0     22      0.000000
# SQL_PUBLIC_IP                                 17     22     77.272727
# SQL_WEAK_ROOT_PASSWORD                         0     22      0.000000
# SSL_NOT_ENFORCED                              14     22     63.636364
# TOO_MANY_KMS_USERS                            24     24    100.000000
# UNENROLLED_BQ4G_BCID_IDENTITY                  0     67      0.000000
# UNENROLLED_REAUTH_IDENTITY                     0     67      0.000000
# USER_MANAGED_SERVICE_ACCOUNT_KEY              23     81     28.395062
# WEAK_SSL_POLICY                                1      8     12.500000
# WEB_UI_ENABLED                                 0     16      0.000000
# WORKLOAD_IDENTITY_DISABLED                    14     16     87.500000
